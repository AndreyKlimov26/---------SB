# %% [markdown]
# # Чтение и запись данных, часть 2
#
# ## Практическая работа
#
# ### Описание практической работы и формат сдачи
#
# Выполните предложенные задачи: сохраните блокнот отдельно себе на диск и после этого пишите код в ячейках под задачами. Итоговый файл в формате `.ipynb` (файл Jupyter Notebook) загрузите в личный кабинет и отправьте на проверку.

# %% [markdown]
# ### Задача 1
#
# Используя сервис WeatherAPI, получите прогноз погоды в Лондоне на следующие 2 дня. Ответ преобразуйте к типу JSON.

# %%
import urllib.request as req
API_KEY = "5eff49003b6447e6a29143652221707"

# %%
days = 2
url = f"http://api.weatherapi.com/v1/forecast.json?key={API_KEY}&q=London&days={days}"
with req.urlopen(url) as session:
  response1 = session.read().decode()

response1
# Out:
# '{"location":{"name":"London","region":"City of London, Greater London","country":"United Kingdom","lat":51.52,"lon":-0.11,"tz_id":"Europe/London","localtime_epoch":1722670269,"localtime":"2024-08-03 8:31"},"current":{"last_updated_epoch":1722669300,"last_updated":"2024-08-03 08:15","temp_c":18.6,"temp_f":65.4,"is_day":1,"condition":{"text":"Patchy rain nearby","icon":"//cdn.weatherapi.com/weather/64x64/day/176.png","code":1063},"wind_mph":7.8,"wind_kph":12.6,"wind_degree":232,"wind_dir":"SW","pressure_mb":1011.0,"pressure_in":29.86,"precip_mm":0.04,"precip_in":0.0,"humidity":83,"cloud":100,"feelslike_c":18.6,"feelslike_f":65.4,"windchill_c":18.6,"windchill_f":65.4,"heatindex_c":18.6,"heatindex_f":65.4,"dewpoint_c":15.7,"dewpoint_f":60.2,"vis_km":10.0,"vis_miles":6.0,"uv":4.0,"gust_mph":10.2,"gust_kph":16.4},"forecast":{"forecastday":[{"date":"2024-08-03","date_epoch":1722643200,"day":{"maxtemp_c":24.8,"maxtemp_f":76.7,"mintemp_c":17.3,"mintemp_f":63.1,"avgtemp_c":20.6,"avgtemp_f":69.1,"maxwind_mph":11.4,"maxwind_kph":18.4,"totalprecip_mm":0.39,"totalprecip_in":0.02,"totalsnow_cm":0.0,"avgvis_km":10.0,"avgvis_miles":6.0,"avghumidity":62,"daily_will_it_rain":1,"daily_chance_of_rain":88,"daily_will_it_snow":0,"daily_chance_of_snow":0,"condition":{"text":"Patchy rain nearby","icon":"//cdn.weatherapi.com/weather/64x64/day/176.png","code":1063},"uv":4.0},"astro":{"sunrise":"05:28 AM","sunset":"08:44 PM","moonrise":"03:37 AM","moonset":"08:53 PM","moon_phase":"Waning Crescent","moon_illumination":2,"is_moon_up":0,"is_sun_up":0},"hour":[{"time_epoch":1722639600,"time":"2024-08-03 00:00","temp_c":19.5,"temp_f":67.2,"is_day":0,"condition":{"text":"Clear ","icon":"//cdn.weatherapi.com/weather/64x64/night/113.png","code":1000},"wind_mph":6.0,"wind_kph":9.7,"wind_degree":238,"wind_dir":"WSW","pressure_mb":1012.0,"pressure_in":29.87,"precip_mm":0.0,"precip_in":0.0,"snow_cm":0.0,"humidity":79,"cloud":21,"feelslike_c":19.5,"feelslike_f":67.2,"windchill_c":19.5,"windchill_f":67.2,"heatindex_c":19.5,"heatindex_f":67.2,"dewpoint_c":15.9,"dewpoint_f":60.6,"will_it_rain":0,"chance_of_rain":0,"will_it_snow":0,"chance_of_snow":0,"vis_km":10.0,"vis_miles":6.0,"gust_mph":8.3,"gust_kph":13.4,"uv":0},{"time_epoch":1722643200,"time":"2024-08-03 01:00","temp_c":18.8,"temp_f":65.8,"is_day":0,"condition":{"text":"Partly Cloudy ","icon":"//cdn.weatherapi.com/weather/64x64/night/116.png","code":1003},"wind_mph":6.5,"wind_kph":10.4,"wind_degree":232,"wind_dir":"SW","pressure_mb":1011.0,"pressure_in":29.86,"precip_mm":0.0,"precip_in":0.0,"snow_cm":0.0,"humidity":83,"cloud":44,"feelslike_c":18.8,"feelslike_f":65.8,"windchill_c":18.8,"windchill_f":65.8,"heatindex_c":18.8,"heatindex_f":65.8,"dewpoint_c":15.9,"dewpoint_f":60.6,"will_it_rain":0,"chance_of_rain":0,"will_it_snow":0,"chance_of_snow":0,"vis_km":10.0,"vis_miles":6.0,"gust_mph":9.0,"gust_kph":14.4,"uv":0},{"time_epoch":1722646800,"time":"2024-08-03 02:00","temp_c":18.4,"temp_f":65.1,"is_day":0,"condition":{"text":"Cloudy ","icon":"//cdn.weatherapi.com/weather/64x64/night/119.png","code":1006},"wind_mph":7.2,"wind_kph":11.5,"wind_degree":236,"wind_dir":"WSW","pressure_mb":1011.0,"pressure_in":29.85,"precip_mm":0.0,"precip_in":0.0,"snow_cm":0.0,"humidity":85,"cloud":67,"feelslike_c":18.4,"feelslike_f":65.1,"windchill_c":18.4,"windchill_f":65.1,"heatindex_c":18.4,"heatindex_f":65.1,"dewpoint_c":15.9,"dewpoint_f":60.6,"will_it_rain":0,"chance_of_rain":0,"will_it_snow":0,"chance_of_snow":0,"vis_km":10.0,"vis_miles":6.0,"gust_mph":9.7,"gust_kph":15.6,"uv":0},{"time_epoch":1722650400,"time":"2024-08-03 03:00","temp_c":18.0,"temp_f":64.4,"is_day":0,"condition":{"text":"Cloudy ","icon":"//cdn.weatherapi.com/weather/64x64/night/119.png","code":1006},"wind_mph":7.2,"wind_kph":11.5,"wind_degree":230,"wind_dir":"SW","pressure_mb":1011.0,"pressure_in":29.84,"precip_mm":0.0,"precip_in":0.0,"snow_cm":0.0,"humidity":86,"cloud":66,"feelslike_c":18.0,"feelslike_f":64.4,"windchill_c":18.0,"windchill_f":64.4,"heatindex_c":18 ...

# %%
import json

data = json.loads(response1)
data
# Out:
# {'location': {'name': 'London',
#   'region': 'City of London, Greater London',
#   'country': 'United Kingdom',
#   'lat': 51.52,
#   'lon': -0.11,
#   'tz_id': 'Europe/London',
#   'localtime_epoch': 1722670269,
#   'localtime': '2024-08-03 8:31'},
#  'current': {'last_updated_epoch': 1722669300,
#   'last_updated': '2024-08-03 08:15',
#   'temp_c': 18.6,
#   'temp_f': 65.4,
#   'is_day': 1,
#   'condition': {'text': 'Patchy rain nearby',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#    'code': 1063},
#   'wind_mph': 7.8,
#   'wind_kph': 12.6,
#   'wind_degree': 232,
#   'wind_dir': 'SW',
#   'pressure_mb': 1011.0,
#   'pressure_in': 29.86,
#   'precip_mm': 0.04,
#   'precip_in': 0.0,
#   'humidity': 83,
#   'cloud': 100,
#   'feelslike_c': 18.6,
#   'feelslike_f': 65.4,
#   'windchill_c': 18.6,
#   'windchill_f': 65.4,
#   'heatindex_c': 18.6,
#   'heatindex_f': 65.4,
#   'dewpoint_c': 15.7,
#   'dewpoint_f': 60.2,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'uv': 4.0,
#   'gust_mph': 10.2,
#   'gust_kph': 16.4},
#  'forecast': {'forecastday': [{'date': '2024-08-03',
#     'date_epoch': 1722643200,
#     'day': {'maxtemp_c': 24.8,
#      'maxtemp_f': 76.7,
#      'mintemp_c': 17.3,
#      'mintemp_f': 63.1,
#      'avgtemp_c': 20.6,
#      'avgtemp_f': 69.1,
#      'maxwind_mph': 11.4,
#      'maxwind_kph': 18.4,
#      'totalprecip_mm': 0.39,
#      'totalprecip_in': 0.02,
#      'totalsnow_cm': 0.0,
#      'avgvis_km': 10.0,
#      'avgvis_miles': 6.0,
#      'avghumidity': 62,
#      'daily_will_it_rain': 1,
#      'daily_chance_of_rain': 88,
#      'daily_will_it_snow': 0,
#      'daily_chance_of_snow': 0,
#      'condition': {'text': 'Patchy rain nearby',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#       'code': 1063},
#      'uv': 4.0},
#     'astro': {'sunrise': '05:28 AM',
#      'sunset': '08:44 PM',
#      'moonrise': '03:37 AM',
#      'moonset': '08:53 PM',
#      'moon_phase': 'Waning Crescent',
#      'moon_illumination': 2,
#      'is_moon_up': 0,
#      'is_sun_up': 0},
#     'hour': [{'time_epoch': 1722639600,
#       'time': '2024-08-03 00:00',
#       'temp_c': 19.5,
#       'temp_f': 67.2,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 6.0,
#       'wind_kph': 9.7,
#       'wind_degree': 238,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1012.0,
#       'pressure_in': 29.87,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 79,
#       'cloud': 21,
#       'feelslike_c': 19.5,
#       'feelslike_f': 67.2,
#       'windchill_c': 19.5,
#       'windchill_f': 67.2,
#       'heatindex_c': 19.5,
#       'heatindex_f': 67.2,
#       'dewpoint_c': 15.9,
#       'dewpoint_f': 60.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.3,
#       'gust_kph': 13.4,
#       'uv': 0},
#      {'time_epoch': 1722643200,
#       'time': '2024-08-03 01:00',
#       'temp_c': 18.8,
#       'temp_f': 65.8,
#       'is_day': 0,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 6.5,
#       'wind_kph': 10.4,
#       'wind_degree': 232,
#       'wind_dir': 'SW',
#       'pressure_mb': 1011.0,
#       'pressure_in': 29.86,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 83,
#       'cloud': 44,
#       'feelslike_c': 18.8,
#       'feelslike_f': 65.8,
#       'windchill_c': 18.8,
#       'windchill_f': 65.8,
#       'heatindex_c': 18.8,
#       'heatindex_f': 65.8,
#       'dewpoint_c': 15.9,
#       'dewpoint_f': 60.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.0,
#       'gust_kph': 14.4,
#       'uv': 0},
#      {'time_epoch': 1722646800,
#       'time': '2024-08-03 02:00',
#       'temp_c': 18.4,
#       'temp_f': 65.1,
#       'is_day': 0,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#        'code': 1006},
#       'wind_mph': 7.2,
#       'wind_kph': 11.5,
#       'wind_degree': 236,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1011.0,
#       'pressure_in': 29.85,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 85,
#       'cloud': 67,
#       'feelslike_c': 18.4,
#       'feelslike_f': 65.1,
#       'windchill_c': 18.4,
#       'windchill_f': 65.1,
#       'heatindex_c': 18.4,
#       'heatindex_f': 65.1,
#       'dewpoint_c': 15.9,
#       'dewpoint_f': 60.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.7,
#       'gust_kph': 15.6,
#       'uv': 0},
#      {'time_epoch': 1722650400,
#       'time': '2024-08-03 03:00',
#       'temp_c': 18.0,
#       'temp_f': 64.4,
#       'is_day': 0,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#        'code': 1006},
#       'wind_mph': 7.2,
#       'wind_kph': 11.5,
#       'wind_degree': 230,
#       'wind_dir': 'SW',
#       'pressure_mb': 1011.0,
#       'pressure_in': 29.84,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 86,
#       'cloud': 66,
#       'feelslike_c': 18.0,
#       'feelslike_f': 64.4,
#       'windchill_c': 18.0,
#       'windchill_f': 64.4,
#       'heatindex_c': 18.0,
#       'heatindex_f': 64.4,
#       'dewpoint_c': 15.6,
#       'dewpoint_f': 60.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.6,
#       'gust_kph': 15.5,
#       'uv': 0},
#      {'time_epoch': 1722654000,
#       'time': '2024-08-03 04:00',
#       'temp_c': 17.8,
#       'temp_f': 64.1,
#       'is_day': 0,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 7.6,
#       'wind_kph': 12.2,
#       'wind_degree': 225,
#       'wind_dir': 'SW',
#       'pressure_mb': 1010.0,
#       'pressure_in': 29.84,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 86,
#       'cloud': 49,
#       'feelslike_c': 17.8,
#       'feelslike_f': 64.1,
#       'windchill_c': 17.8,
#       'windchill_f': 64.1,
#       'heatindex_c': 17.8,
#       'heatindex_f': 64.1,
#       'dewpoint_c': 15.4,
#       'dewpoint_f': 59.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.3,
#       'gust_kph': 16.5,
#       'uv': 0},
#      {'time_epoch': 1722657600,
#       'time': '2024-08-03 05:00',
#       'temp_c': 18.0,
#       'temp_f': 64.5,
#       'is_day': 0,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 7.8,
#       'wind_kph': 12.6,
#       'wind_degree': 232,
#       'wind_dir': 'SW',
#       'pressure_mb': 1011.0,
#       'pressure_in': 29.84,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 82,
#       'cloud': 54,
#       'feelslike_c': 18.0,
#       'feelslike_f': 64.5,
#       'windchill_c': 18.0,
#       'windchill_f': 64.5,
#       'heatindex_c': 18.0,
#       'heatindex_f': 64.5,
#       'dewpoint_c': 15.0,
#       'dewpoint_f': 58.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.4,
#       'gust_kph': 16.8,
#       'uv': 0},
#      {'time_epoch': 1722661200,
#       'time': '2024-08-03 06:00',
#       'temp_c': 18.2,
#       'temp_f': 64.7,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 7.6,
#       'wind_kph': 12.2,
#       'wind_degree': 230,
#       'wind_dir': 'SW',
#       'pressure_mb': 1011.0,
#       'pressure_in': 29.85,
#       'precip_mm': 0.01,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 81,
#       'cloud': 100,
#       'feelslike_c': 18.2,
#       'feelslike_f': 64.7,
#       'windchill_c': 18.2,
#       'windchill_f': 64.7,
#       'heatindex_c': 18.2,
#       'heatindex_f': 64.7,
#       'dewpoint_c': 14.9,
#       'dewpoint_f': 58.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 62,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.0,
#       'gust_kph': 16.2,
#       'uv': 4.0},
#      {'time_epoch': 1722664800,
#       'time': '2024-08-03 07:00',
#       'temp_c': 18.1,
#       'temp_f': 64.6,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 7.6,
#       'wind_kph': 12.2,
#       'wind_degree': 230,
#       'wind_dir': 'SW',
#       'pressure_mb': 1011.0,
#       'pressure_in': 29.85,
#       'precip_mm': 0.1,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 83,
#       'cloud': 100,
#       'feelslike_c': 18.1,
#       'feelslike_f': 64.6,
#       'windchill_c': 18.1,
#       'windchill_f': 64.6,
#       'heatindex_c': 18.1,
#       'heatindex_f': 64.6,
#       'dewpoint_c': 15.3,
#       'dewpoint_f': 59.5,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.0,
#       'gust_kph': 16.1,
#       'uv': 4.0},
#      {'time_epoch': 1722668400,
#       'time': '2024-08-03 08:00',
#       'temp_c': 18.6,
#       'temp_f': 65.4,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 7.8,
#       'wind_kph': 12.6,
#       'wind_degree': 232,
#       'wind_dir': 'SW',
#       'pressure_mb': 1011.0,
#       'pressure_in': 29.86,
#       'precip_mm': 0.04,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 83,
#       'cloud': 100,
#       'feelslike_c': 18.6,
#       'feelslike_f': 65.4,
#       'windchill_c': 18.6,
#       'windchill_f': 65.4,
#       'heatindex_c': 18.6,
#       'heatindex_f': 65.4,
#       'dewpoint_c': 15.7,
#       'dewpoint_f': 60.2,
#       'will_it_rain': 1,
#       'chance_of_rain': 85,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.2,
#       'gust_kph': 16.4,
#       'uv': 4.0},
#      {'time_epoch': 1722672000,
#       'time': '2024-08-03 09:00',
#       'temp_c': 20.2,
#       'temp_f': 68.4,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 7.8,
#       'wind_kph': 12.6,
#       'wind_degree': 244,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1011.0,
#       'pressure_in': 29.85,
#       'precip_mm': 0.02,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 75,
#       'cloud': 100,
#       'feelslike_c': 20.2,
#       'feelslike_f': 68.4,
#       'windchill_c': 20.2,
#       'windchill_f': 68.4,
#       'heatindex_c': 20.2,
#       'heatindex_f': 68.4,
#       'dewpoint_c': 15.7,
#       'dewpoint_f': 60.3,
#       'will_it_rain': 1,
#       'chance_of_rain': 84,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.3,
#       'gust_kph': 14.9,
#       'uv': 5.0},
#      {'time_epoch': 1722675600,
#       'time': '2024-08-03 10:00',
#       'temp_c': 21.7,
#       'temp_f': 71.0,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 7.6,
#       'wind_kph': 12.2,
#       'wind_degree': 250,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1011.0,
#       'pressure_in': 29.85,
#       'precip_mm': 0.04,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 66,
#       'cloud': 100,
#       'feelslike_c': 21.7,
#       'feelslike_f': 71.0,
#       'windchill_c': 21.7,
#       'windchill_f': 71.0,
#       'heatindex_c': 24.5,
#       'heatindex_f': 76.1,
#       'dewpoint_c': 15.0,
#       'dewpoint_f': 59.0,
#       'will_it_rain': 1,
#       'chance_of_rain': 88,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.7,
#       'gust_kph': 14.1,
#       'uv': 5.0},
#      {'time_epoch': 1722679200,
#       'time': '2024-08-03 11:00',
#       'temp_c': 22.9,
#       'temp_f': 73.2,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 8.7,
#       'wind_kph': 14.0,
#       'wind_degree': 254,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1011.0,
#       'pressure_in': 29.85,
#       'precip_mm': 0.15,
#       'precip_in': 0.01,
#       'snow_cm': 0.0,
#       'humidity': 58,
#       'cloud': 98,
#       'feelslike_c': 24.9,
#       'feelslike_f': 76.7,
#       'windchill_c': 22.9,
#       'windchill_f': 73.2,
#       'heatindex_c': 24.9,
#       'heatindex_f': 76.7,
#       'dewpoint_c': 14.3,
#       'dewpoint_f': 57.7,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.1,
#       'gust_kph': 16.3,
#       'uv': 5.0},
#      {'time_epoch': 1722682800,
#       'time': '2024-08-03 12:00',
#       'temp_c': 23.5,
#       'temp_f': 74.3,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 10.3,
#       'wind_kph': 16.6,
#       'wind_degree': 250,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1010.0,
#       'pressure_in': 29.84,
#       'precip_mm': 0.03,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 54,
#       'cloud': 100,
#       'feelslike_c': 25.0,
#       'feelslike_f': 77.1,
#       'windchill_c': 23.5,
#       'windchill_f': 74.3,
#       'heatindex_c': 25.0,
#       'heatindex_f': 77.1,
#       'dewpoint_c': 13.6,
#       'dewpoint_f': 56.4,
#       'will_it_rain': 1,
#       'chance_of_rain': 87,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.0,
#       'gust_kph': 19.3,
#       'uv': 5.0},
#      {'time_epoch': 1722686400,
#       'time': '2024-08-03 13:00',
#       'temp_c': 24.2,
#       'temp_f': 75.6,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 11.4,
#       'wind_kph': 18.4,
#       'wind_degree': 254,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1010.0,
#       'pressure_in': 29.84,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 46,
#       'cloud': 86,
#       'feelslike_c': 25.2,
#       'feelslike_f': 77.3,
#       'windchill_c': 24.2,
#       'windchill_f': 75.6,
#       'heatindex_c': 25.2,
#       'heatindex_f': 77.3,
#       'dewpoint_c': 11.8,
#       'dewpoint_f': 53.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.1,
#       'gust_kph': 21.1,
#       'uv': 5.0},
#      {'time_epoch': 1722690000,
#       'time': '2024-08-03 14:00',
#       'temp_c': 24.7,
#       'temp_f': 76.4,
#       'is_day': 1,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 10.5,
#       'wind_kph': 16.9,
#       'wind_degree': 260,
#       'wind_dir': 'W',
#       'pressure_mb': 1010.0,
#       'pressure_in': 29.83,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 38,
#       'cloud': 26,
#       'feelslike_c': 25.0,
#       'feelslike_f': 77.1,
#       'windchill_c': 24.7,
#       'windchill_f': 76.4,
#       'heatindex_c': 25.0,
#       'heatindex_f': 77.1,
#       'dewpoint_c': 9.3,
#       'dewpoint_f': 48.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.1,
#       'gust_kph': 19.5,
#       'uv': 6.0},
#      {'time_epoch': 1722693600,
#       'time': '2024-08-03 15:00',
#       'temp_c': 24.8,
#       'temp_f': 76.7,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 10.7,
#       'wind_kph': 17.3,
#       'wind_degree': 277,
#       'wind_dir': 'W',
#       'pressure_mb': 1010.0,
#       'pressure_in': 29.84,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 35,
#       'cloud': 4,
#       'feelslike_c': 24.9,
#       'feelslike_f': 76.9,
#       'windchill_c': 24.8,
#       'windchill_f': 76.7,
#       'heatindex_c': 24.9,
#       'heatindex_f': 76.9,
#       'dewpoint_c': 8.3,
#       'dewpoint_f': 46.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.3,
#       'gust_kph': 19.9,
#       'uv': 6.0},
#      {'time_epoch': 1722697200,
#       'time': '2024-08-03 16:00',
#       'temp_c': 24.6,
#       'temp_f': 76.2,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 10.1,
#       'wind_kph': 16.2,
#       'wind_degree': 283,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1010.0,
#       'pressure_in': 29.83,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 36,
#       'cloud': 7,
#       'feelslike_c': 24.9,
#       'feelslike_f': 76.7,
#       'windchill_c': 24.6,
#       'windchill_f': 76.2,
#       'heatindex_c': 24.9,
#       'heatindex_f': 76.7,
#       'dewpoint_c': 8.4,
#       'dewpoint_f': 47.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.6,
#       'gust_kph': 18.6,
#       'uv': 6.0},
#      {'time_epoch': 1722700800,
#       'time': '2024-08-03 17:00',
#       'temp_c': 23.9,
#       'temp_f': 75.0,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 10.7,
#       'wind_kph': 17.3,
#       'wind_degree': 300,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1010.0,
#       'pressure_in': 29.83,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 39,
#       'cloud': 3,
#       'feelslike_c': 24.6,
#       'feelslike_f': 76.4,
#       'windchill_c': 23.9,
#       'windchill_f': 75.0,
#       'heatindex_c': 24.6,
#       'heatindex_f': 76.4,
#       'dewpoint_c': 8.9,
#       'dewpoint_f': 48.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.5,
#       'gust_kph': 20.1,
#       'uv': 6.0},
#      {'time_epoch': 1722704400,
#       'time': '2024-08-03 18:00',
#       'temp_c': 22.6,
#       'temp_f': 72.7,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 10.7,
#       'wind_kph': 17.3,
#       'wind_degree': 307,
#       'wind_dir': 'NW',
#       'pressure_mb': 1011.0,
#       'pressure_in': 29.85,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 40,
#       'cloud': 14,
#       'feelslike_c': 24.2,
#       'feelslike_f': 75.6,
#       'windchill_c': 22.6,
#       'windchill_f': 72.7,
#       'heatindex_c': 24.2,
#       'heatindex_f': 75.6,
#       'dewpoint_c': 8.4,
#       'dewpoint_f': 47.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.4,
#       'gust_kph': 21.6,
#       'uv': 6.0},
#      {'time_epoch': 1722708000,
#       'time': '2024-08-03 19:00',
#       'temp_c': 21.5,
#       'temp_f': 70.7,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 8.7,
#       'wind_kph': 14.0,
#       'wind_degree': 308,
#       'wind_dir': 'NW',
#       'pressure_mb': 1012.0,
#       'pressure_in': 29.87,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 43,
#       'cloud': 11,
#       'feelslike_c': 21.5,
#       'feelslike_f': 70.7,
#       'windchill_c': 21.5,
#       'windchill_f': 70.7,
#       'heatindex_c': 24.1,
#       'heatindex_f': 75.3,
#       'dewpoint_c': 8.3,
#       'dewpoint_f': 46.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.1,
#       'gust_kph': 19.5,
#       'uv': 6.0},
#      {'time_epoch': 1722711600,
#       'time': '2024-08-03 20:00',
#       'temp_c': 20.2,
#       'temp_f': 68.4,
#       'is_day': 1,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 7.6,
#       'wind_kph': 12.2,
#       'wind_degree': 308,
#       'wind_dir': 'NW',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.9,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 47,
#       'cloud': 46,
#       'feelslike_c': 20.2,
#       'feelslike_f': 68.4,
#       'windchill_c': 20.2,
#       'windchill_f': 68.4,
#       'heatindex_c': 20.2,
#       'heatindex_f': 68.4,
#       'dewpoint_c': 8.5,
#       'dewpoint_f': 47.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.4,
#       'gust_kph': 18.3,
#       'uv': 6.0},
#      {'time_epoch': 1722715200,
#       'time': '2024-08-03 21:00',
#       'temp_c': 19.4,
#       'temp_f': 66.9,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 7.6,
#       'wind_kph': 12.2,
#       'wind_degree': 301,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.92,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 50,
#       'cloud': 24,
#       'feelslike_c': 19.4,
#       'feelslike_f': 66.9,
#       'windchill_c': 19.4,
#       'windchill_f': 66.9,
#       'heatindex_c': 19.4,
#       'heatindex_f': 66.9,
#       'dewpoint_c': 8.9,
#       'dewpoint_f': 47.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.1,
#       'gust_kph': 17.8,
#       'uv': 0},
#      {'time_epoch': 1722718800,
#       'time': '2024-08-03 22:00',
#       'temp_c': 18.1,
#       'temp_f': 64.6,
#       'is_day': 0,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 8.9,
#       'wind_kph': 14.4,
#       'wind_degree': 303,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.94,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 55,
#       'cloud': 26,
#       'feelslike_c': 18.1,
#       'feelslike_f': 64.6,
#       'windchill_c': 18.1,
#       'windchill_f': 64.6,
#       'heatindex_c': 18.1,
#       'heatindex_f': 64.6,
#       'dewpoint_c': 9.0,
#       'dewpoint_f': 48.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.5,
#       'gust_kph': 20.1,
#       'uv': 0},
#      {'time_epoch': 1722722400,
#       'time': '2024-08-03 23:00',
#       'temp_c': 17.3,
#       'temp_f': 63.1,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 7.4,
#       'wind_kph': 11.9,
#       'wind_degree': 306,
#       'wind_dir': 'NW',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.95,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 57,
#       'cloud': 5,
#       'feelslike_c': 17.3,
#       'feelslike_f': 63.1,
#       'windchill_c': 17.3,
#       'windchill_f': 63.1,
#       'heatindex_c': 17.3,
#       'heatindex_f': 63.1,
#       'dewpoint_c': 8.8,
#       'dewpoint_f': 47.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.5,
#       'gust_kph': 16.8,
#       'uv': 0}]},
#    {'date': '2024-08-04',
#     'date_epoch': 1722729600,
#     'day': {'maxtemp_c': 21.5,
#      'maxtemp_f': 70.7,
#      'mintemp_c': 15.0,
#      'mintemp_f': 59.1,
#      'avgtemp_c': 18.1,
#      'avgtemp_f': 64.6,
#      'maxwind_mph': 6.7,
#      'maxwind_kph': 10.8,
#      'totalprecip_mm': 0.0,
#      'totalprecip_in': 0.0,
#      'totalsnow_cm': 0.0,
#      'avgvis_km': 10.0,
#      'avgvis_miles': 6.0,
#      'avghumidity': 56,
#      'daily_will_it_rain': 0,
#      'daily_chance_of_rain': 0,
#      'daily_will_it_snow': 0,
#      'daily_chance_of_snow': 0,
#      'condition': {'text': 'Partly Cloudy ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#       'code': 1003},
#      'uv': 3.0},
#     'astro': {'sunrise': '05:30 AM',
#      'sunset': '08:43 PM',
#      'moonrise': '04:54 AM',
#      'moonset': '09:13 PM',
#      'moon_phase': 'New Moon',
#      'moon_illumination': 0,
#      'is_moon_up': 0,
#      'is_sun_up': 0},
#     'hour': [{'time_epoch': 1722726000,
#       'time': '2024-08-04 00:00',
#       'temp_c': 16.7,
#       'temp_f': 62.1,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 6.3,
#       'wind_kph': 10.1,
#       'wind_degree': 305,
#       'wind_dir': 'NW',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.95,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 60,
#       'cloud': 3,
#       'feelslike_c': 16.7,
#       'feelslike_f': 62.1,
#       'windchill_c': 16.7,
#       'windchill_f': 62.1,
#       'heatindex_c': 16.7,
#       'heatindex_f': 62.1,
#       'dewpoint_c': 8.9,
#       'dewpoint_f': 47.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.0,
#       'gust_kph': 14.4,
#       'uv': 0},
#      {'time_epoch': 1722729600,
#       'time': '2024-08-04 01:00',
#       'temp_c': 16.2,
#       'temp_f': 61.2,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 5.6,
#       'wind_kph': 9.0,
#       'wind_degree': 313,
#       'wind_dir': 'NW',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.96,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 62,
#       'cloud': 3,
#       'feelslike_c': 16.2,
#       'feelslike_f': 61.2,
#       'windchill_c': 16.2,
#       'windchill_f': 61.2,
#       'heatindex_c': 16.2,
#       'heatindex_f': 61.2,
#       'dewpoint_c': 8.9,
#       'dewpoint_f': 48.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.9,
#       'gust_kph': 12.8,
#       'uv': 0},
#      {'time_epoch': 1722733200,
#       'time': '2024-08-04 02:00',
#       'temp_c': 15.8,
#       'temp_f': 60.5,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.5,
#       'wind_kph': 7.2,
#       'wind_degree': 316,
#       'wind_dir': 'NW',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.95,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 63,
#       'cloud': 6,
#       'feelslike_c': 15.8,
#       'feelslike_f': 60.5,
#       'windchill_c': 15.8,
#       'windchill_f': 60.5,
#       'heatindex_c': 15.8,
#       'heatindex_f': 60.5,
#       'dewpoint_c': 8.7,
#       'dewpoint_f': 47.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.3,
#       'gust_kph': 10.2,
#       'uv': 0},
#      {'time_epoch': 1722736800,
#       'time': '2024-08-04 03:00',
#       'temp_c': 15.5,
#       'temp_f': 59.9,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.0,
#       'wind_kph': 6.5,
#       'wind_degree': 316,
#       'wind_dir': 'NW',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.95,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 63,
#       'cloud': 9,
#       'feelslike_c': 15.5,
#       'feelslike_f': 59.9,
#       'windchill_c': 15.5,
#       'windchill_f': 59.9,
#       'heatindex_c': 15.5,
#       'heatindex_f': 59.9,
#       'dewpoint_c': 8.6,
#       'dewpoint_f': 47.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.7,
#       'gust_kph': 9.2,
#       'uv': 0},
#      {'time_epoch': 1722740400,
#       'time': '2024-08-04 04:00',
#       'temp_c': 15.2,
#       'temp_f': 59.4,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 3.6,
#       'wind_kph': 5.8,
#       'wind_degree': 307,
#       'wind_dir': 'NW',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.96,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 64,
#       'cloud': 13,
#       'feelslike_c': 15.2,
#       'feelslike_f': 59.4,
#       'windchill_c': 15.2,
#       'windchill_f': 59.4,
#       'heatindex_c': 15.2,
#       'heatindex_f': 59.4,
#       'dewpoint_c': 8.5,
#       'dewpoint_f': 47.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.1,
#       'gust_kph': 8.2,
#       'uv': 0},
#      {'time_epoch': 1722744000,
#       'time': '2024-08-04 05:00',
#       'temp_c': 15.0,
#       'temp_f': 59.1,
#       'is_day': 0,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 3.8,
#       'wind_kph': 6.1,
#       'wind_degree': 297,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.98,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 65,
#       'cloud': 33,
#       'feelslike_c': 15.0,
#       'feelslike_f': 59.1,
#       'windchill_c': 15.0,
#       'windchill_f': 59.1,
#       'heatindex_c': 15.0,
#       'heatindex_f': 59.1,
#       'dewpoint_c': 8.5,
#       'dewpoint_f': 47.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.4,
#       'gust_kph': 8.7,
#       'uv': 0},
#      {'time_epoch': 1722747600,
#       'time': '2024-08-04 06:00',
#       'temp_c': 15.5,
#       'temp_f': 59.8,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 3.8,
#       'wind_kph': 6.1,
#       'wind_degree': 292,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1016.0,
#       'pressure_in': 29.99,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 63,
#       'cloud': 70,
#       'feelslike_c': 15.5,
#       'feelslike_f': 59.8,
#       'windchill_c': 15.5,
#       'windchill_f': 59.8,
#       'heatindex_c': 15.5,
#       'heatindex_f': 59.8,
#       'dewpoint_c': 8.5,
#       'dewpoint_f': 47.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.0,
#       'gust_kph': 8.1,
#       'uv': 4.0},
#      {'time_epoch': 1722751200,
#       'time': '2024-08-04 07:00',
#       'temp_c': 16.2,
#       'temp_f': 61.2,
#       'is_day': 1,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 3.1,
#       'wind_kph': 5.0,
#       'wind_degree': 273,
#       'wind_dir': 'W',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.0,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 60,
#       'cloud': 48,
#       'feelslike_c': 16.2,
#       'feelslike_f': 61.2,
#       'windchill_c': 16.2,
#       'windchill_f': 61.2,
#       'heatindex_c': 16.2,
#       'heatindex_f': 61.2,
#       'dewpoint_c': 8.5,
#       'dewpoint_f': 47.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 3.9,
#       'gust_kph': 6.2,
#       'uv': 5.0},
#      {'time_epoch': 1722754800,
#       'time': '2024-08-04 08:00',
#       'temp_c': 17.1,
#       'temp_f': 62.9,
#       'is_day': 1,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 3.6,
#       'wind_kph': 5.8,
#       'wind_degree': 267,
#       'wind_dir': 'W',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.0,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 56,
#       'cloud': 49,
#       'feelslike_c': 17.1,
#       'feelslike_f': 62.9,
#       'windchill_c': 17.1,
#       'windchill_f': 62.9,
#       'heatindex_c': 17.1,
#       'heatindex_f': 62.9,
#       'dewpoint_c': 8.4,
#       'dewpoint_f': 47.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.2,
#       'gust_kph': 6.7,
#       'uv': 5.0},
#      {'time_epoch': 1722758400,
#       'time': '2024-08-04 09:00',
#       'temp_c': 17.6,
#       'temp_f': 63.7,
#       'is_day': 1,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 4.5,
#       'wind_kph': 7.2,
#       'wind_degree': 259,
#       'wind_dir': 'W',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.0,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 53,
#       'cloud': 47,
#       'feelslike_c': 17.6,
#       'feelslike_f': 63.7,
#       'windchill_c': 17.6,
#       'windchill_f': 63.7,
#       'heatindex_c': 17.6,
#       'heatindex_f': 63.7,
#       'dewpoint_c': 8.1,
#       'dewpoint_f': 46.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.2,
#       'gust_kph': 8.4,
#       'uv': 5.0},
#      {'time_epoch': 1722762000,
#       'time': '2024-08-04 10:00',
#       'temp_c': 18.1,
#       'temp_f': 64.5,
#       'is_day': 1,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 4.0,
#       'wind_kph': 6.5,
#       'wind_degree': 259,
#       'wind_dir': 'W',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.01,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 51,
#       'cloud': 48,
#       'feelslike_c': 18.1,
#       'feelslike_f': 64.5,
#       'windchill_c': 18.1,
#       'windchill_f': 64.5,
#       'heatindex_c': 18.1,
#       'heatindex_f': 64.5,
#       'dewpoint_c': 7.8,
#       'dewpoint_f': 46.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.6,
#       'gust_kph': 7.5,
#       'uv': 5.0},
#      {'time_epoch': 1722765600,
#       'time': '2024-08-04 11:00',
#       'temp_c': 19.7,
#       'temp_f': 67.4,
#       'is_day': 1,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 4.5,
#       'wind_kph': 7.2,
#       'wind_degree': 251,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.0,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 45,
#       'cloud': 47,
#       'feelslike_c': 19.7,
#       'feelslike_f': 67.4,
#       'windchill_c': 19.7,
#       'windchill_f': 67.4,
#       'heatindex_c': 19.7,
#       'heatindex_f': 67.4,
#       'dewpoint_c': 7.5,
#       'dewpoint_f': 45.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.1,
#       'gust_kph': 8.3,
#       'uv': 5.0},
#      {'time_epoch': 1722769200,
#       'time': '2024-08-04 12:00',
#       'temp_c': 20.2,
#       'temp_f': 68.4,
#       'is_day': 1,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 4.5,
#       'wind_kph': 7.2,
#       'wind_degree': 254,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1016.0,
#       'pressure_in': 29.99,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 43,
#       'cloud': 47,
#       'feelslike_c': 20.2,
#       'feelslike_f': 68.3,
#       'windchill_c': 20.2,
#       'windchill_f': 68.3,
#       'heatindex_c': 20.2,
#       'heatindex_f': 68.3,
#       'dewpoint_c': 7.2,
#       'dewpoint_f': 45.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.1,
#       'gust_kph': 8.3,
#       'uv': 6.0},
#      {'time_epoch': 1722772800,
#       'time': '2024-08-04 13:00',
#       'temp_c': 19.9,
#       'temp_f': 67.9,
#       'is_day': 1,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 3.8,
#       'wind_kph': 6.1,
#       'wind_degree': 262,
#       'wind_dir': 'W',
#       'pressure_mb': 1016.0,
#       'pressure_in': 29.99,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 44,
#       'cloud': 50,
#       'feelslike_c': 19.9,
#       'feelslike_f': 67.9,
#       'windchill_c': 19.9,
#       'windchill_f': 67.9,
#       'heatindex_c': 19.9,
#       'heatindex_f': 67.9,
#       'dewpoint_c': 7.2,
#       'dewpoint_f': 45.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.6,
#       'gust_kph': 7.4,
#       'uv': 5.0},
#      {'time_epoch': 1722776400,
#       'time': '2024-08-04 14:00',
#       'temp_c': 20.1,
#       'temp_f': 68.3,
#       'is_day': 1,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 3.8,
#       'wind_kph': 6.1,
#       'wind_degree': 275,
#       'wind_dir': 'W',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.98,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 44,
#       'cloud': 29,
#       'feelslike_c': 20.1,
#       'feelslike_f': 68.3,
#       'windchill_c': 20.1,
#       'windchill_f': 68.3,
#       'heatindex_c': 20.1,
#       'heatindex_f': 68.3,
#       'dewpoint_c': 7.7,
#       'dewpoint_f': 45.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.9,
#       'gust_kph': 7.8,
#       'uv': 6.0},
#      {'time_epoch': 1722780000,
#       'time': '2024-08-04 15:00',
#       'temp_c': 20.5,
#       'temp_f': 68.8,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 4.0,
#       'wind_kph': 6.5,
#       'wind_degree': 280,
#       'wind_dir': 'W',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.97,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 46,
#       'cloud': 21,
#       'feelslike_c': 20.5,
#       'feelslike_f': 68.8,
#       'windchill_c': 20.5,
#       'windchill_f': 68.8,
#       'heatindex_c': 20.5,
#       'heatindex_f': 68.8,
#       'dewpoint_c': 8.4,
#       'dewpoint_f': 47.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.2,
#       'gust_kph': 8.4,
#       'uv': 6.0},
#      {'time_epoch': 1722783600,
#       'time': '2024-08-04 16:00',
#       'temp_c': 20.8,
#       'temp_f': 69.4,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 4.5,
#       'wind_kph': 7.2,
#       'wind_degree': 291,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.96,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 48,
#       'cloud': 15,
#       'feelslike_c': 20.8,
#       'feelslike_f': 69.4,
#       'windchill_c': 20.8,
#       'windchill_f': 69.4,
#       'heatindex_c': 20.8,
#       'heatindex_f': 69.4,
#       'dewpoint_c': 9.3,
#       'dewpoint_f': 48.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.7,
#       'gust_kph': 9.3,
#       'uv': 6.0},
#      {'time_epoch': 1722787200,
#       'time': '2024-08-04 17:00',
#       'temp_c': 21.5,
#       'temp_f': 70.7,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 3.8,
#       'wind_kph': 6.1,
#       'wind_degree': 271,
#       'wind_dir': 'W',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.96,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 47,
#       'cloud': 24,
#       'feelslike_c': 21.5,
#       'feelslike_f': 70.8,
#       'windchill_c': 21.5,
#       'windchill_f': 70.8,
#       'heatindex_c': 24.2,
#       'heatindex_f': 75.6,
#       'dewpoint_c': 9.7,
#       'dewpoint_f': 49.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.7,
#       'gust_kph': 7.5,
#       'uv': 6.0},
#      {'time_epoch': 1722790800,
#       'time': '2024-08-04 18:00',
#       'temp_c': 21.5,
#       'temp_f': 70.7,
#       'is_day': 1,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 2.9,
#       'wind_kph': 4.7,
#       'wind_degree': 236,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.95,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 48,
#       'cloud': 43,
#       'feelslike_c': 21.5,
#       'feelslike_f': 70.7,
#       'windchill_c': 21.5,
#       'windchill_f': 70.7,
#       'heatindex_c': 24.3,
#       'heatindex_f': 75.7,
#       'dewpoint_c': 10.1,
#       'dewpoint_f': 50.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 3.8,
#       'gust_kph': 6.0,
#       'uv': 6.0},
#      {'time_epoch': 1722794400,
#       'time': '2024-08-04 19:00',
#       'temp_c': 20.3,
#       'temp_f': 68.5,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 3.6,
#       'wind_kph': 5.8,
#       'wind_degree': 185,
#       'wind_dir': 'S',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.95,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 54,
#       'cloud': 22,
#       'feelslike_c': 20.3,
#       'feelslike_f': 68.5,
#       'windchill_c': 20.3,
#       'windchill_f': 68.5,
#       'heatindex_c': 20.3,
#       'heatindex_f': 68.5,
#       'dewpoint_c': 10.6,
#       'dewpoint_f': 51.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.1,
#       'gust_kph': 8.2,
#       'uv': 6.0},
#      {'time_epoch': 1722798000,
#       'time': '2024-08-04 20:00',
#       'temp_c': 18.8,
#       'temp_f': 65.8,
#       'is_day': 1,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 4.3,
#       'wind_kph': 6.8,
#       'wind_degree': 210,
#       'wind_dir': 'SSW',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.98,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 60,
#       'cloud': 33,
#       'feelslike_c': 18.8,
#       'feelslike_f': 65.8,
#       'windchill_c': 18.8,
#       'windchill_f': 65.8,
#       'heatindex_c': 18.8,
#       'heatindex_f': 65.8,
#       'dewpoint_c': 10.9,
#       'dewpoint_f': 51.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.4,
#       'gust_kph': 10.4,
#       'uv': 5.0},
#      {'time_epoch': 1722801600,
#       'time': '2024-08-04 21:00',
#       'temp_c': 18.1,
#       'temp_f': 64.7,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 5.4,
#       'wind_kph': 8.6,
#       'wind_degree': 214,
#       'wind_dir': 'SW',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.98,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 64,
#       'cloud': 24,
#       'feelslike_c': 18.1,
#       'feelslike_f': 64.7,
#       'windchill_c': 18.1,
#       'windchill_f': 64.7,
#       'heatindex_c': 18.1,
#       'heatindex_f': 64.7,
#       'dewpoint_c': 11.2,
#       'dewpoint_f': 52.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.0,
#       'gust_kph': 12.9,
#       'uv': 0},
#      {'time_epoch': 1722805200,
#       'time': '2024-08-04 22:00',
#       'temp_c': 17.4,
#       'temp_f': 63.3,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 6.7,
#       'wind_kph': 10.8,
#       'wind_degree': 222,
#       'wind_dir': 'SW',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.98,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 68,
#       'cloud': 23,
#       'feelslike_c': 17.4,
#       'feelslike_f': 63.3,
#       'windchill_c': 17.4,
#       'windchill_f': 63.3,
#       'heatindex_c': 17.4,
#       'heatindex_f': 63.3,
#       'dewpoint_c': 11.5,
#       'dewpoint_f': 52.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.6,
#       'gust_kph': 15.5,
#       'uv': 0},
#      {'time_epoch': 1722808800,
#       'time': '2024-08-04 23:00',
#       'temp_c': 16.7,
#       'temp_f': 62.1,
#       'is_day': 0,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 6.3,
#       'wind_kph': 10.1,
#       'wind_degree': 228,
#       'wind_dir': 'SW',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.97,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 72,
#       'cloud': 26,
#       'feelslike_c': 16.7,
#       'feelslike_f': 62.1,
#       'windchill_c': 16.7,
#       'windchill_f': 62.1,
#       'heatindex_c': 16.7,
#       'heatindex_f': 62.1,
#       'dewpoint_c': 11.7,
#       'dewpoint_f': 53.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.9,
#       'gust_kph': 14.3,
#       'uv': 0}]}]}}

# %%
len(data['forecast']['forecastday'])
# Out:
# 2

# %% [markdown]
# ### Задача 2
#
# Сохраните данные погоды, полученные в предыдущей задаче, в файл `weather.json`. При сохранении используйте четыре пробела для форматирования.

# %%
with req.urlopen(url) as session:
  response1 = session.read().decode()
  s = json.loads(response1)

s
# Out:
# {'location': {'name': 'London',
#   'region': 'City of London, Greater London',
#   'country': 'United Kingdom',
#   'lat': 51.52,
#   'lon': -0.11,
#   'tz_id': 'Europe/London',
#   'localtime_epoch': 1722670269,
#   'localtime': '2024-08-03 8:31'},
#  'current': {'last_updated_epoch': 1722669300,
#   'last_updated': '2024-08-03 08:15',
#   'temp_c': 18.6,
#   'temp_f': 65.4,
#   'is_day': 1,
#   'condition': {'text': 'Patchy rain nearby',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#    'code': 1063},
#   'wind_mph': 7.8,
#   'wind_kph': 12.6,
#   'wind_degree': 232,
#   'wind_dir': 'SW',
#   'pressure_mb': 1011.0,
#   'pressure_in': 29.86,
#   'precip_mm': 0.04,
#   'precip_in': 0.0,
#   'humidity': 83,
#   'cloud': 100,
#   'feelslike_c': 18.6,
#   'feelslike_f': 65.4,
#   'windchill_c': 18.6,
#   'windchill_f': 65.4,
#   'heatindex_c': 18.6,
#   'heatindex_f': 65.4,
#   'dewpoint_c': 15.7,
#   'dewpoint_f': 60.2,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'uv': 4.0,
#   'gust_mph': 10.2,
#   'gust_kph': 16.4},
#  'forecast': {'forecastday': [{'date': '2024-08-03',
#     'date_epoch': 1722643200,
#     'day': {'maxtemp_c': 24.8,
#      'maxtemp_f': 76.7,
#      'mintemp_c': 17.3,
#      'mintemp_f': 63.1,
#      'avgtemp_c': 20.6,
#      'avgtemp_f': 69.1,
#      'maxwind_mph': 11.4,
#      'maxwind_kph': 18.4,
#      'totalprecip_mm': 0.39,
#      'totalprecip_in': 0.02,
#      'totalsnow_cm': 0.0,
#      'avgvis_km': 10.0,
#      'avgvis_miles': 6.0,
#      'avghumidity': 62,
#      'daily_will_it_rain': 1,
#      'daily_chance_of_rain': 88,
#      'daily_will_it_snow': 0,
#      'daily_chance_of_snow': 0,
#      'condition': {'text': 'Patchy rain nearby',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#       'code': 1063},
#      'uv': 4.0},
#     'astro': {'sunrise': '05:28 AM',
#      'sunset': '08:44 PM',
#      'moonrise': '03:37 AM',
#      'moonset': '08:53 PM',
#      'moon_phase': 'Waning Crescent',
#      'moon_illumination': 2,
#      'is_moon_up': 0,
#      'is_sun_up': 0},
#     'hour': [{'time_epoch': 1722639600,
#       'time': '2024-08-03 00:00',
#       'temp_c': 19.5,
#       'temp_f': 67.2,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 6.0,
#       'wind_kph': 9.7,
#       'wind_degree': 238,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1012.0,
#       'pressure_in': 29.87,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 79,
#       'cloud': 21,
#       'feelslike_c': 19.5,
#       'feelslike_f': 67.2,
#       'windchill_c': 19.5,
#       'windchill_f': 67.2,
#       'heatindex_c': 19.5,
#       'heatindex_f': 67.2,
#       'dewpoint_c': 15.9,
#       'dewpoint_f': 60.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.3,
#       'gust_kph': 13.4,
#       'uv': 0},
#      {'time_epoch': 1722643200,
#       'time': '2024-08-03 01:00',
#       'temp_c': 18.8,
#       'temp_f': 65.8,
#       'is_day': 0,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 6.5,
#       'wind_kph': 10.4,
#       'wind_degree': 232,
#       'wind_dir': 'SW',
#       'pressure_mb': 1011.0,
#       'pressure_in': 29.86,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 83,
#       'cloud': 44,
#       'feelslike_c': 18.8,
#       'feelslike_f': 65.8,
#       'windchill_c': 18.8,
#       'windchill_f': 65.8,
#       'heatindex_c': 18.8,
#       'heatindex_f': 65.8,
#       'dewpoint_c': 15.9,
#       'dewpoint_f': 60.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.0,
#       'gust_kph': 14.4,
#       'uv': 0},
#      {'time_epoch': 1722646800,
#       'time': '2024-08-03 02:00',
#       'temp_c': 18.4,
#       'temp_f': 65.1,
#       'is_day': 0,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#        'code': 1006},
#       'wind_mph': 7.2,
#       'wind_kph': 11.5,
#       'wind_degree': 236,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1011.0,
#       'pressure_in': 29.85,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 85,
#       'cloud': 67,
#       'feelslike_c': 18.4,
#       'feelslike_f': 65.1,
#       'windchill_c': 18.4,
#       'windchill_f': 65.1,
#       'heatindex_c': 18.4,
#       'heatindex_f': 65.1,
#       'dewpoint_c': 15.9,
#       'dewpoint_f': 60.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.7,
#       'gust_kph': 15.6,
#       'uv': 0},
#      {'time_epoch': 1722650400,
#       'time': '2024-08-03 03:00',
#       'temp_c': 18.0,
#       'temp_f': 64.4,
#       'is_day': 0,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#        'code': 1006},
#       'wind_mph': 7.2,
#       'wind_kph': 11.5,
#       'wind_degree': 230,
#       'wind_dir': 'SW',
#       'pressure_mb': 1011.0,
#       'pressure_in': 29.84,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 86,
#       'cloud': 66,
#       'feelslike_c': 18.0,
#       'feelslike_f': 64.4,
#       'windchill_c': 18.0,
#       'windchill_f': 64.4,
#       'heatindex_c': 18.0,
#       'heatindex_f': 64.4,
#       'dewpoint_c': 15.6,
#       'dewpoint_f': 60.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.6,
#       'gust_kph': 15.5,
#       'uv': 0},
#      {'time_epoch': 1722654000,
#       'time': '2024-08-03 04:00',
#       'temp_c': 17.8,
#       'temp_f': 64.1,
#       'is_day': 0,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 7.6,
#       'wind_kph': 12.2,
#       'wind_degree': 225,
#       'wind_dir': 'SW',
#       'pressure_mb': 1010.0,
#       'pressure_in': 29.84,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 86,
#       'cloud': 49,
#       'feelslike_c': 17.8,
#       'feelslike_f': 64.1,
#       'windchill_c': 17.8,
#       'windchill_f': 64.1,
#       'heatindex_c': 17.8,
#       'heatindex_f': 64.1,
#       'dewpoint_c': 15.4,
#       'dewpoint_f': 59.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.3,
#       'gust_kph': 16.5,
#       'uv': 0},
#      {'time_epoch': 1722657600,
#       'time': '2024-08-03 05:00',
#       'temp_c': 18.0,
#       'temp_f': 64.5,
#       'is_day': 0,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 7.8,
#       'wind_kph': 12.6,
#       'wind_degree': 232,
#       'wind_dir': 'SW',
#       'pressure_mb': 1011.0,
#       'pressure_in': 29.84,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 82,
#       'cloud': 54,
#       'feelslike_c': 18.0,
#       'feelslike_f': 64.5,
#       'windchill_c': 18.0,
#       'windchill_f': 64.5,
#       'heatindex_c': 18.0,
#       'heatindex_f': 64.5,
#       'dewpoint_c': 15.0,
#       'dewpoint_f': 58.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.4,
#       'gust_kph': 16.8,
#       'uv': 0},
#      {'time_epoch': 1722661200,
#       'time': '2024-08-03 06:00',
#       'temp_c': 18.2,
#       'temp_f': 64.7,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 7.6,
#       'wind_kph': 12.2,
#       'wind_degree': 230,
#       'wind_dir': 'SW',
#       'pressure_mb': 1011.0,
#       'pressure_in': 29.85,
#       'precip_mm': 0.01,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 81,
#       'cloud': 100,
#       'feelslike_c': 18.2,
#       'feelslike_f': 64.7,
#       'windchill_c': 18.2,
#       'windchill_f': 64.7,
#       'heatindex_c': 18.2,
#       'heatindex_f': 64.7,
#       'dewpoint_c': 14.9,
#       'dewpoint_f': 58.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 62,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.0,
#       'gust_kph': 16.2,
#       'uv': 4.0},
#      {'time_epoch': 1722664800,
#       'time': '2024-08-03 07:00',
#       'temp_c': 18.1,
#       'temp_f': 64.6,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 7.6,
#       'wind_kph': 12.2,
#       'wind_degree': 230,
#       'wind_dir': 'SW',
#       'pressure_mb': 1011.0,
#       'pressure_in': 29.85,
#       'precip_mm': 0.1,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 83,
#       'cloud': 100,
#       'feelslike_c': 18.1,
#       'feelslike_f': 64.6,
#       'windchill_c': 18.1,
#       'windchill_f': 64.6,
#       'heatindex_c': 18.1,
#       'heatindex_f': 64.6,
#       'dewpoint_c': 15.3,
#       'dewpoint_f': 59.5,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.0,
#       'gust_kph': 16.1,
#       'uv': 4.0},
#      {'time_epoch': 1722668400,
#       'time': '2024-08-03 08:00',
#       'temp_c': 18.6,
#       'temp_f': 65.4,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 7.8,
#       'wind_kph': 12.6,
#       'wind_degree': 232,
#       'wind_dir': 'SW',
#       'pressure_mb': 1011.0,
#       'pressure_in': 29.86,
#       'precip_mm': 0.04,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 83,
#       'cloud': 100,
#       'feelslike_c': 18.6,
#       'feelslike_f': 65.4,
#       'windchill_c': 18.6,
#       'windchill_f': 65.4,
#       'heatindex_c': 18.6,
#       'heatindex_f': 65.4,
#       'dewpoint_c': 15.7,
#       'dewpoint_f': 60.2,
#       'will_it_rain': 1,
#       'chance_of_rain': 85,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.2,
#       'gust_kph': 16.4,
#       'uv': 4.0},
#      {'time_epoch': 1722672000,
#       'time': '2024-08-03 09:00',
#       'temp_c': 20.2,
#       'temp_f': 68.4,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 7.8,
#       'wind_kph': 12.6,
#       'wind_degree': 244,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1011.0,
#       'pressure_in': 29.85,
#       'precip_mm': 0.02,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 75,
#       'cloud': 100,
#       'feelslike_c': 20.2,
#       'feelslike_f': 68.4,
#       'windchill_c': 20.2,
#       'windchill_f': 68.4,
#       'heatindex_c': 20.2,
#       'heatindex_f': 68.4,
#       'dewpoint_c': 15.7,
#       'dewpoint_f': 60.3,
#       'will_it_rain': 1,
#       'chance_of_rain': 84,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.3,
#       'gust_kph': 14.9,
#       'uv': 5.0},
#      {'time_epoch': 1722675600,
#       'time': '2024-08-03 10:00',
#       'temp_c': 21.7,
#       'temp_f': 71.0,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 7.6,
#       'wind_kph': 12.2,
#       'wind_degree': 250,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1011.0,
#       'pressure_in': 29.85,
#       'precip_mm': 0.04,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 66,
#       'cloud': 100,
#       'feelslike_c': 21.7,
#       'feelslike_f': 71.0,
#       'windchill_c': 21.7,
#       'windchill_f': 71.0,
#       'heatindex_c': 24.5,
#       'heatindex_f': 76.1,
#       'dewpoint_c': 15.0,
#       'dewpoint_f': 59.0,
#       'will_it_rain': 1,
#       'chance_of_rain': 88,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.7,
#       'gust_kph': 14.1,
#       'uv': 5.0},
#      {'time_epoch': 1722679200,
#       'time': '2024-08-03 11:00',
#       'temp_c': 22.9,
#       'temp_f': 73.2,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 8.7,
#       'wind_kph': 14.0,
#       'wind_degree': 254,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1011.0,
#       'pressure_in': 29.85,
#       'precip_mm': 0.15,
#       'precip_in': 0.01,
#       'snow_cm': 0.0,
#       'humidity': 58,
#       'cloud': 98,
#       'feelslike_c': 24.9,
#       'feelslike_f': 76.7,
#       'windchill_c': 22.9,
#       'windchill_f': 73.2,
#       'heatindex_c': 24.9,
#       'heatindex_f': 76.7,
#       'dewpoint_c': 14.3,
#       'dewpoint_f': 57.7,
#       'will_it_rain': 1,
#       'chance_of_rain': 100,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.1,
#       'gust_kph': 16.3,
#       'uv': 5.0},
#      {'time_epoch': 1722682800,
#       'time': '2024-08-03 12:00',
#       'temp_c': 23.5,
#       'temp_f': 74.3,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 10.3,
#       'wind_kph': 16.6,
#       'wind_degree': 250,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1010.0,
#       'pressure_in': 29.84,
#       'precip_mm': 0.03,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 54,
#       'cloud': 100,
#       'feelslike_c': 25.0,
#       'feelslike_f': 77.1,
#       'windchill_c': 23.5,
#       'windchill_f': 74.3,
#       'heatindex_c': 25.0,
#       'heatindex_f': 77.1,
#       'dewpoint_c': 13.6,
#       'dewpoint_f': 56.4,
#       'will_it_rain': 1,
#       'chance_of_rain': 87,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.0,
#       'gust_kph': 19.3,
#       'uv': 5.0},
#      {'time_epoch': 1722686400,
#       'time': '2024-08-03 13:00',
#       'temp_c': 24.2,
#       'temp_f': 75.6,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 11.4,
#       'wind_kph': 18.4,
#       'wind_degree': 254,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1010.0,
#       'pressure_in': 29.84,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 46,
#       'cloud': 86,
#       'feelslike_c': 25.2,
#       'feelslike_f': 77.3,
#       'windchill_c': 24.2,
#       'windchill_f': 75.6,
#       'heatindex_c': 25.2,
#       'heatindex_f': 77.3,
#       'dewpoint_c': 11.8,
#       'dewpoint_f': 53.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.1,
#       'gust_kph': 21.1,
#       'uv': 5.0},
#      {'time_epoch': 1722690000,
#       'time': '2024-08-03 14:00',
#       'temp_c': 24.7,
#       'temp_f': 76.4,
#       'is_day': 1,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 10.5,
#       'wind_kph': 16.9,
#       'wind_degree': 260,
#       'wind_dir': 'W',
#       'pressure_mb': 1010.0,
#       'pressure_in': 29.83,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 38,
#       'cloud': 26,
#       'feelslike_c': 25.0,
#       'feelslike_f': 77.1,
#       'windchill_c': 24.7,
#       'windchill_f': 76.4,
#       'heatindex_c': 25.0,
#       'heatindex_f': 77.1,
#       'dewpoint_c': 9.3,
#       'dewpoint_f': 48.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.1,
#       'gust_kph': 19.5,
#       'uv': 6.0},
#      {'time_epoch': 1722693600,
#       'time': '2024-08-03 15:00',
#       'temp_c': 24.8,
#       'temp_f': 76.7,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 10.7,
#       'wind_kph': 17.3,
#       'wind_degree': 277,
#       'wind_dir': 'W',
#       'pressure_mb': 1010.0,
#       'pressure_in': 29.84,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 35,
#       'cloud': 4,
#       'feelslike_c': 24.9,
#       'feelslike_f': 76.9,
#       'windchill_c': 24.8,
#       'windchill_f': 76.7,
#       'heatindex_c': 24.9,
#       'heatindex_f': 76.9,
#       'dewpoint_c': 8.3,
#       'dewpoint_f': 46.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.3,
#       'gust_kph': 19.9,
#       'uv': 6.0},
#      {'time_epoch': 1722697200,
#       'time': '2024-08-03 16:00',
#       'temp_c': 24.6,
#       'temp_f': 76.2,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 10.1,
#       'wind_kph': 16.2,
#       'wind_degree': 283,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1010.0,
#       'pressure_in': 29.83,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 36,
#       'cloud': 7,
#       'feelslike_c': 24.9,
#       'feelslike_f': 76.7,
#       'windchill_c': 24.6,
#       'windchill_f': 76.2,
#       'heatindex_c': 24.9,
#       'heatindex_f': 76.7,
#       'dewpoint_c': 8.4,
#       'dewpoint_f': 47.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.6,
#       'gust_kph': 18.6,
#       'uv': 6.0},
#      {'time_epoch': 1722700800,
#       'time': '2024-08-03 17:00',
#       'temp_c': 23.9,
#       'temp_f': 75.0,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 10.7,
#       'wind_kph': 17.3,
#       'wind_degree': 300,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1010.0,
#       'pressure_in': 29.83,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 39,
#       'cloud': 3,
#       'feelslike_c': 24.6,
#       'feelslike_f': 76.4,
#       'windchill_c': 23.9,
#       'windchill_f': 75.0,
#       'heatindex_c': 24.6,
#       'heatindex_f': 76.4,
#       'dewpoint_c': 8.9,
#       'dewpoint_f': 48.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.5,
#       'gust_kph': 20.1,
#       'uv': 6.0},
#      {'time_epoch': 1722704400,
#       'time': '2024-08-03 18:00',
#       'temp_c': 22.6,
#       'temp_f': 72.7,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 10.7,
#       'wind_kph': 17.3,
#       'wind_degree': 307,
#       'wind_dir': 'NW',
#       'pressure_mb': 1011.0,
#       'pressure_in': 29.85,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 40,
#       'cloud': 14,
#       'feelslike_c': 24.2,
#       'feelslike_f': 75.6,
#       'windchill_c': 22.6,
#       'windchill_f': 72.7,
#       'heatindex_c': 24.2,
#       'heatindex_f': 75.6,
#       'dewpoint_c': 8.4,
#       'dewpoint_f': 47.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.4,
#       'gust_kph': 21.6,
#       'uv': 6.0},
#      {'time_epoch': 1722708000,
#       'time': '2024-08-03 19:00',
#       'temp_c': 21.5,
#       'temp_f': 70.7,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 8.7,
#       'wind_kph': 14.0,
#       'wind_degree': 308,
#       'wind_dir': 'NW',
#       'pressure_mb': 1012.0,
#       'pressure_in': 29.87,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 43,
#       'cloud': 11,
#       'feelslike_c': 21.5,
#       'feelslike_f': 70.7,
#       'windchill_c': 21.5,
#       'windchill_f': 70.7,
#       'heatindex_c': 24.1,
#       'heatindex_f': 75.3,
#       'dewpoint_c': 8.3,
#       'dewpoint_f': 46.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.1,
#       'gust_kph': 19.5,
#       'uv': 6.0},
#      {'time_epoch': 1722711600,
#       'time': '2024-08-03 20:00',
#       'temp_c': 20.2,
#       'temp_f': 68.4,
#       'is_day': 1,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 7.6,
#       'wind_kph': 12.2,
#       'wind_degree': 308,
#       'wind_dir': 'NW',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.9,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 47,
#       'cloud': 46,
#       'feelslike_c': 20.2,
#       'feelslike_f': 68.4,
#       'windchill_c': 20.2,
#       'windchill_f': 68.4,
#       'heatindex_c': 20.2,
#       'heatindex_f': 68.4,
#       'dewpoint_c': 8.5,
#       'dewpoint_f': 47.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.4,
#       'gust_kph': 18.3,
#       'uv': 6.0},
#      {'time_epoch': 1722715200,
#       'time': '2024-08-03 21:00',
#       'temp_c': 19.4,
#       'temp_f': 66.9,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 7.6,
#       'wind_kph': 12.2,
#       'wind_degree': 301,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.92,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 50,
#       'cloud': 24,
#       'feelslike_c': 19.4,
#       'feelslike_f': 66.9,
#       'windchill_c': 19.4,
#       'windchill_f': 66.9,
#       'heatindex_c': 19.4,
#       'heatindex_f': 66.9,
#       'dewpoint_c': 8.9,
#       'dewpoint_f': 47.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.1,
#       'gust_kph': 17.8,
#       'uv': 0},
#      {'time_epoch': 1722718800,
#       'time': '2024-08-03 22:00',
#       'temp_c': 18.1,
#       'temp_f': 64.6,
#       'is_day': 0,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 8.9,
#       'wind_kph': 14.4,
#       'wind_degree': 303,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.94,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 55,
#       'cloud': 26,
#       'feelslike_c': 18.1,
#       'feelslike_f': 64.6,
#       'windchill_c': 18.1,
#       'windchill_f': 64.6,
#       'heatindex_c': 18.1,
#       'heatindex_f': 64.6,
#       'dewpoint_c': 9.0,
#       'dewpoint_f': 48.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.5,
#       'gust_kph': 20.1,
#       'uv': 0},
#      {'time_epoch': 1722722400,
#       'time': '2024-08-03 23:00',
#       'temp_c': 17.3,
#       'temp_f': 63.1,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 7.4,
#       'wind_kph': 11.9,
#       'wind_degree': 306,
#       'wind_dir': 'NW',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.95,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 57,
#       'cloud': 5,
#       'feelslike_c': 17.3,
#       'feelslike_f': 63.1,
#       'windchill_c': 17.3,
#       'windchill_f': 63.1,
#       'heatindex_c': 17.3,
#       'heatindex_f': 63.1,
#       'dewpoint_c': 8.8,
#       'dewpoint_f': 47.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.5,
#       'gust_kph': 16.8,
#       'uv': 0}]},
#    {'date': '2024-08-04',
#     'date_epoch': 1722729600,
#     'day': {'maxtemp_c': 21.5,
#      'maxtemp_f': 70.7,
#      'mintemp_c': 15.0,
#      'mintemp_f': 59.1,
#      'avgtemp_c': 18.1,
#      'avgtemp_f': 64.6,
#      'maxwind_mph': 6.7,
#      'maxwind_kph': 10.8,
#      'totalprecip_mm': 0.0,
#      'totalprecip_in': 0.0,
#      'totalsnow_cm': 0.0,
#      'avgvis_km': 10.0,
#      'avgvis_miles': 6.0,
#      'avghumidity': 56,
#      'daily_will_it_rain': 0,
#      'daily_chance_of_rain': 0,
#      'daily_will_it_snow': 0,
#      'daily_chance_of_snow': 0,
#      'condition': {'text': 'Partly Cloudy ',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#       'code': 1003},
#      'uv': 3.0},
#     'astro': {'sunrise': '05:30 AM',
#      'sunset': '08:43 PM',
#      'moonrise': '04:54 AM',
#      'moonset': '09:13 PM',
#      'moon_phase': 'New Moon',
#      'moon_illumination': 0,
#      'is_moon_up': 0,
#      'is_sun_up': 0},
#     'hour': [{'time_epoch': 1722726000,
#       'time': '2024-08-04 00:00',
#       'temp_c': 16.7,
#       'temp_f': 62.1,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 6.3,
#       'wind_kph': 10.1,
#       'wind_degree': 305,
#       'wind_dir': 'NW',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.95,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 60,
#       'cloud': 3,
#       'feelslike_c': 16.7,
#       'feelslike_f': 62.1,
#       'windchill_c': 16.7,
#       'windchill_f': 62.1,
#       'heatindex_c': 16.7,
#       'heatindex_f': 62.1,
#       'dewpoint_c': 8.9,
#       'dewpoint_f': 47.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.0,
#       'gust_kph': 14.4,
#       'uv': 0},
#      {'time_epoch': 1722729600,
#       'time': '2024-08-04 01:00',
#       'temp_c': 16.2,
#       'temp_f': 61.2,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 5.6,
#       'wind_kph': 9.0,
#       'wind_degree': 313,
#       'wind_dir': 'NW',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.96,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 62,
#       'cloud': 3,
#       'feelslike_c': 16.2,
#       'feelslike_f': 61.2,
#       'windchill_c': 16.2,
#       'windchill_f': 61.2,
#       'heatindex_c': 16.2,
#       'heatindex_f': 61.2,
#       'dewpoint_c': 8.9,
#       'dewpoint_f': 48.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.9,
#       'gust_kph': 12.8,
#       'uv': 0},
#      {'time_epoch': 1722733200,
#       'time': '2024-08-04 02:00',
#       'temp_c': 15.8,
#       'temp_f': 60.5,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.5,
#       'wind_kph': 7.2,
#       'wind_degree': 316,
#       'wind_dir': 'NW',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.95,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 63,
#       'cloud': 6,
#       'feelslike_c': 15.8,
#       'feelslike_f': 60.5,
#       'windchill_c': 15.8,
#       'windchill_f': 60.5,
#       'heatindex_c': 15.8,
#       'heatindex_f': 60.5,
#       'dewpoint_c': 8.7,
#       'dewpoint_f': 47.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.3,
#       'gust_kph': 10.2,
#       'uv': 0},
#      {'time_epoch': 1722736800,
#       'time': '2024-08-04 03:00',
#       'temp_c': 15.5,
#       'temp_f': 59.9,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.0,
#       'wind_kph': 6.5,
#       'wind_degree': 316,
#       'wind_dir': 'NW',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.95,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 63,
#       'cloud': 9,
#       'feelslike_c': 15.5,
#       'feelslike_f': 59.9,
#       'windchill_c': 15.5,
#       'windchill_f': 59.9,
#       'heatindex_c': 15.5,
#       'heatindex_f': 59.9,
#       'dewpoint_c': 8.6,
#       'dewpoint_f': 47.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.7,
#       'gust_kph': 9.2,
#       'uv': 0},
#      {'time_epoch': 1722740400,
#       'time': '2024-08-04 04:00',
#       'temp_c': 15.2,
#       'temp_f': 59.4,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 3.6,
#       'wind_kph': 5.8,
#       'wind_degree': 307,
#       'wind_dir': 'NW',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.96,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 64,
#       'cloud': 13,
#       'feelslike_c': 15.2,
#       'feelslike_f': 59.4,
#       'windchill_c': 15.2,
#       'windchill_f': 59.4,
#       'heatindex_c': 15.2,
#       'heatindex_f': 59.4,
#       'dewpoint_c': 8.5,
#       'dewpoint_f': 47.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.1,
#       'gust_kph': 8.2,
#       'uv': 0},
#      {'time_epoch': 1722744000,
#       'time': '2024-08-04 05:00',
#       'temp_c': 15.0,
#       'temp_f': 59.1,
#       'is_day': 0,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 3.8,
#       'wind_kph': 6.1,
#       'wind_degree': 297,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.98,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 65,
#       'cloud': 33,
#       'feelslike_c': 15.0,
#       'feelslike_f': 59.1,
#       'windchill_c': 15.0,
#       'windchill_f': 59.1,
#       'heatindex_c': 15.0,
#       'heatindex_f': 59.1,
#       'dewpoint_c': 8.5,
#       'dewpoint_f': 47.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.4,
#       'gust_kph': 8.7,
#       'uv': 0},
#      {'time_epoch': 1722747600,
#       'time': '2024-08-04 06:00',
#       'temp_c': 15.5,
#       'temp_f': 59.8,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 3.8,
#       'wind_kph': 6.1,
#       'wind_degree': 292,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1016.0,
#       'pressure_in': 29.99,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 63,
#       'cloud': 70,
#       'feelslike_c': 15.5,
#       'feelslike_f': 59.8,
#       'windchill_c': 15.5,
#       'windchill_f': 59.8,
#       'heatindex_c': 15.5,
#       'heatindex_f': 59.8,
#       'dewpoint_c': 8.5,
#       'dewpoint_f': 47.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.0,
#       'gust_kph': 8.1,
#       'uv': 4.0},
#      {'time_epoch': 1722751200,
#       'time': '2024-08-04 07:00',
#       'temp_c': 16.2,
#       'temp_f': 61.2,
#       'is_day': 1,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 3.1,
#       'wind_kph': 5.0,
#       'wind_degree': 273,
#       'wind_dir': 'W',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.0,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 60,
#       'cloud': 48,
#       'feelslike_c': 16.2,
#       'feelslike_f': 61.2,
#       'windchill_c': 16.2,
#       'windchill_f': 61.2,
#       'heatindex_c': 16.2,
#       'heatindex_f': 61.2,
#       'dewpoint_c': 8.5,
#       'dewpoint_f': 47.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 3.9,
#       'gust_kph': 6.2,
#       'uv': 5.0},
#      {'time_epoch': 1722754800,
#       'time': '2024-08-04 08:00',
#       'temp_c': 17.1,
#       'temp_f': 62.9,
#       'is_day': 1,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 3.6,
#       'wind_kph': 5.8,
#       'wind_degree': 267,
#       'wind_dir': 'W',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.0,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 56,
#       'cloud': 49,
#       'feelslike_c': 17.1,
#       'feelslike_f': 62.9,
#       'windchill_c': 17.1,
#       'windchill_f': 62.9,
#       'heatindex_c': 17.1,
#       'heatindex_f': 62.9,
#       'dewpoint_c': 8.4,
#       'dewpoint_f': 47.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.2,
#       'gust_kph': 6.7,
#       'uv': 5.0},
#      {'time_epoch': 1722758400,
#       'time': '2024-08-04 09:00',
#       'temp_c': 17.6,
#       'temp_f': 63.7,
#       'is_day': 1,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 4.5,
#       'wind_kph': 7.2,
#       'wind_degree': 259,
#       'wind_dir': 'W',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.0,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 53,
#       'cloud': 47,
#       'feelslike_c': 17.6,
#       'feelslike_f': 63.7,
#       'windchill_c': 17.6,
#       'windchill_f': 63.7,
#       'heatindex_c': 17.6,
#       'heatindex_f': 63.7,
#       'dewpoint_c': 8.1,
#       'dewpoint_f': 46.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.2,
#       'gust_kph': 8.4,
#       'uv': 5.0},
#      {'time_epoch': 1722762000,
#       'time': '2024-08-04 10:00',
#       'temp_c': 18.1,
#       'temp_f': 64.5,
#       'is_day': 1,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 4.0,
#       'wind_kph': 6.5,
#       'wind_degree': 259,
#       'wind_dir': 'W',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.01,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 51,
#       'cloud': 48,
#       'feelslike_c': 18.1,
#       'feelslike_f': 64.5,
#       'windchill_c': 18.1,
#       'windchill_f': 64.5,
#       'heatindex_c': 18.1,
#       'heatindex_f': 64.5,
#       'dewpoint_c': 7.8,
#       'dewpoint_f': 46.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.6,
#       'gust_kph': 7.5,
#       'uv': 5.0},
#      {'time_epoch': 1722765600,
#       'time': '2024-08-04 11:00',
#       'temp_c': 19.7,
#       'temp_f': 67.4,
#       'is_day': 1,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 4.5,
#       'wind_kph': 7.2,
#       'wind_degree': 251,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.0,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 45,
#       'cloud': 47,
#       'feelslike_c': 19.7,
#       'feelslike_f': 67.4,
#       'windchill_c': 19.7,
#       'windchill_f': 67.4,
#       'heatindex_c': 19.7,
#       'heatindex_f': 67.4,
#       'dewpoint_c': 7.5,
#       'dewpoint_f': 45.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.1,
#       'gust_kph': 8.3,
#       'uv': 5.0},
#      {'time_epoch': 1722769200,
#       'time': '2024-08-04 12:00',
#       'temp_c': 20.2,
#       'temp_f': 68.4,
#       'is_day': 1,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 4.5,
#       'wind_kph': 7.2,
#       'wind_degree': 254,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1016.0,
#       'pressure_in': 29.99,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 43,
#       'cloud': 47,
#       'feelslike_c': 20.2,
#       'feelslike_f': 68.3,
#       'windchill_c': 20.2,
#       'windchill_f': 68.3,
#       'heatindex_c': 20.2,
#       'heatindex_f': 68.3,
#       'dewpoint_c': 7.2,
#       'dewpoint_f': 45.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.1,
#       'gust_kph': 8.3,
#       'uv': 6.0},
#      {'time_epoch': 1722772800,
#       'time': '2024-08-04 13:00',
#       'temp_c': 19.9,
#       'temp_f': 67.9,
#       'is_day': 1,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 3.8,
#       'wind_kph': 6.1,
#       'wind_degree': 262,
#       'wind_dir': 'W',
#       'pressure_mb': 1016.0,
#       'pressure_in': 29.99,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 44,
#       'cloud': 50,
#       'feelslike_c': 19.9,
#       'feelslike_f': 67.9,
#       'windchill_c': 19.9,
#       'windchill_f': 67.9,
#       'heatindex_c': 19.9,
#       'heatindex_f': 67.9,
#       'dewpoint_c': 7.2,
#       'dewpoint_f': 45.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.6,
#       'gust_kph': 7.4,
#       'uv': 5.0},
#      {'time_epoch': 1722776400,
#       'time': '2024-08-04 14:00',
#       'temp_c': 20.1,
#       'temp_f': 68.3,
#       'is_day': 1,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 3.8,
#       'wind_kph': 6.1,
#       'wind_degree': 275,
#       'wind_dir': 'W',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.98,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 44,
#       'cloud': 29,
#       'feelslike_c': 20.1,
#       'feelslike_f': 68.3,
#       'windchill_c': 20.1,
#       'windchill_f': 68.3,
#       'heatindex_c': 20.1,
#       'heatindex_f': 68.3,
#       'dewpoint_c': 7.7,
#       'dewpoint_f': 45.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.9,
#       'gust_kph': 7.8,
#       'uv': 6.0},
#      {'time_epoch': 1722780000,
#       'time': '2024-08-04 15:00',
#       'temp_c': 20.5,
#       'temp_f': 68.8,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 4.0,
#       'wind_kph': 6.5,
#       'wind_degree': 280,
#       'wind_dir': 'W',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.97,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 46,
#       'cloud': 21,
#       'feelslike_c': 20.5,
#       'feelslike_f': 68.8,
#       'windchill_c': 20.5,
#       'windchill_f': 68.8,
#       'heatindex_c': 20.5,
#       'heatindex_f': 68.8,
#       'dewpoint_c': 8.4,
#       'dewpoint_f': 47.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.2,
#       'gust_kph': 8.4,
#       'uv': 6.0},
#      {'time_epoch': 1722783600,
#       'time': '2024-08-04 16:00',
#       'temp_c': 20.8,
#       'temp_f': 69.4,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 4.5,
#       'wind_kph': 7.2,
#       'wind_degree': 291,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.96,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 48,
#       'cloud': 15,
#       'feelslike_c': 20.8,
#       'feelslike_f': 69.4,
#       'windchill_c': 20.8,
#       'windchill_f': 69.4,
#       'heatindex_c': 20.8,
#       'heatindex_f': 69.4,
#       'dewpoint_c': 9.3,
#       'dewpoint_f': 48.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.7,
#       'gust_kph': 9.3,
#       'uv': 6.0},
#      {'time_epoch': 1722787200,
#       'time': '2024-08-04 17:00',
#       'temp_c': 21.5,
#       'temp_f': 70.7,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 3.8,
#       'wind_kph': 6.1,
#       'wind_degree': 271,
#       'wind_dir': 'W',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.96,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 47,
#       'cloud': 24,
#       'feelslike_c': 21.5,
#       'feelslike_f': 70.8,
#       'windchill_c': 21.5,
#       'windchill_f': 70.8,
#       'heatindex_c': 24.2,
#       'heatindex_f': 75.6,
#       'dewpoint_c': 9.7,
#       'dewpoint_f': 49.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.7,
#       'gust_kph': 7.5,
#       'uv': 6.0},
#      {'time_epoch': 1722790800,
#       'time': '2024-08-04 18:00',
#       'temp_c': 21.5,
#       'temp_f': 70.7,
#       'is_day': 1,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 2.9,
#       'wind_kph': 4.7,
#       'wind_degree': 236,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.95,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 48,
#       'cloud': 43,
#       'feelslike_c': 21.5,
#       'feelslike_f': 70.7,
#       'windchill_c': 21.5,
#       'windchill_f': 70.7,
#       'heatindex_c': 24.3,
#       'heatindex_f': 75.7,
#       'dewpoint_c': 10.1,
#       'dewpoint_f': 50.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 3.8,
#       'gust_kph': 6.0,
#       'uv': 6.0},
#      {'time_epoch': 1722794400,
#       'time': '2024-08-04 19:00',
#       'temp_c': 20.3,
#       'temp_f': 68.5,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 3.6,
#       'wind_kph': 5.8,
#       'wind_degree': 185,
#       'wind_dir': 'S',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.95,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 54,
#       'cloud': 22,
#       'feelslike_c': 20.3,
#       'feelslike_f': 68.5,
#       'windchill_c': 20.3,
#       'windchill_f': 68.5,
#       'heatindex_c': 20.3,
#       'heatindex_f': 68.5,
#       'dewpoint_c': 10.6,
#       'dewpoint_f': 51.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.1,
#       'gust_kph': 8.2,
#       'uv': 6.0},
#      {'time_epoch': 1722798000,
#       'time': '2024-08-04 20:00',
#       'temp_c': 18.8,
#       'temp_f': 65.8,
#       'is_day': 1,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 4.3,
#       'wind_kph': 6.8,
#       'wind_degree': 210,
#       'wind_dir': 'SSW',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.98,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 60,
#       'cloud': 33,
#       'feelslike_c': 18.8,
#       'feelslike_f': 65.8,
#       'windchill_c': 18.8,
#       'windchill_f': 65.8,
#       'heatindex_c': 18.8,
#       'heatindex_f': 65.8,
#       'dewpoint_c': 10.9,
#       'dewpoint_f': 51.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.4,
#       'gust_kph': 10.4,
#       'uv': 5.0},
#      {'time_epoch': 1722801600,
#       'time': '2024-08-04 21:00',
#       'temp_c': 18.1,
#       'temp_f': 64.7,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 5.4,
#       'wind_kph': 8.6,
#       'wind_degree': 214,
#       'wind_dir': 'SW',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.98,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 64,
#       'cloud': 24,
#       'feelslike_c': 18.1,
#       'feelslike_f': 64.7,
#       'windchill_c': 18.1,
#       'windchill_f': 64.7,
#       'heatindex_c': 18.1,
#       'heatindex_f': 64.7,
#       'dewpoint_c': 11.2,
#       'dewpoint_f': 52.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.0,
#       'gust_kph': 12.9,
#       'uv': 0},
#      {'time_epoch': 1722805200,
#       'time': '2024-08-04 22:00',
#       'temp_c': 17.4,
#       'temp_f': 63.3,
#       'is_day': 0,
#       'condition': {'text': 'Clear ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 6.7,
#       'wind_kph': 10.8,
#       'wind_degree': 222,
#       'wind_dir': 'SW',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.98,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 68,
#       'cloud': 23,
#       'feelslike_c': 17.4,
#       'feelslike_f': 63.3,
#       'windchill_c': 17.4,
#       'windchill_f': 63.3,
#       'heatindex_c': 17.4,
#       'heatindex_f': 63.3,
#       'dewpoint_c': 11.5,
#       'dewpoint_f': 52.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.6,
#       'gust_kph': 15.5,
#       'uv': 0},
#      {'time_epoch': 1722808800,
#       'time': '2024-08-04 23:00',
#       'temp_c': 16.7,
#       'temp_f': 62.1,
#       'is_day': 0,
#       'condition': {'text': 'Partly Cloudy ',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 6.3,
#       'wind_kph': 10.1,
#       'wind_degree': 228,
#       'wind_dir': 'SW',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.97,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 72,
#       'cloud': 26,
#       'feelslike_c': 16.7,
#       'feelslike_f': 62.1,
#       'windchill_c': 16.7,
#       'windchill_f': 62.1,
#       'heatindex_c': 16.7,
#       'heatindex_f': 62.1,
#       'dewpoint_c': 11.7,
#       'dewpoint_f': 53.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.9,
#       'gust_kph': 14.3,
#       'uv': 0}]}]}}

# %%
with open('weather.json', 'w') as file:
    json.dump(s, file, indent=4)

# %% [markdown]
# ### Задача 3
#
# Из содержимого файла `weather.json` получите **почасовой** прогноз погоды, загрузите его в DataFrame и выведите первые пять строк DataFrame на экран.

# %%
import pandas as pd

d = []

for i in range(days):
  d_outer = data['forecast']['forecastday'][i]
  d = d + d_outer['hour']
df = pd.DataFrame(d)
df.head()
# Out:
#    time_epoch              time  temp_c  temp_f  is_day  \
# 0  1722639600  2024-08-03 00:00    19.5    67.2       0
# 1  1722643200  2024-08-03 01:00    18.8    65.8       0
# 2  1722646800  2024-08-03 02:00    18.4    65.1       0
# 3  1722650400  2024-08-03 03:00    18.0    64.4       0
# 4  1722654000  2024-08-03 04:00    17.8    64.1       0
#
#                                            condition  wind_mph  wind_kph  \
# 0  {'text': 'Clear ', 'icon': '//cdn.weatherapi.c...       6.0       9.7
# 1  {'text': 'Partly Cloudy ', 'icon': '//cdn.weat...       6.5      10.4
# 2  {'text': 'Cloudy ', 'icon': '//cdn.weatherapi....       7.2      11.5
# 3  {'text': 'Cloudy ', 'icon': '//cdn.weatherapi....       7.2      11.5
# 4  {'text': 'Partly Cloudy ', 'icon': '//cdn.weat...       7.6      12.2
#
#    wind_degree wind_dir  ...  dewpoint_f  will_it_rain  chance_of_rain  \
# 0          238      WSW  ...        60.6             0               0
# 1          232       SW  ...        60.6             0               0
# 2          236      WSW  ...        60.6             0               0
# 3          230       SW  ...        60.1             0               0
# 4          225       SW  ...        59.7             0               0
#
#    will_it_snow  chance_of_snow  vis_km  vis_miles  gust_mph  gust_kph   uv
# 0             0               0    10.0        6.0       8.3      13.4  0.0
# 1             0               0    10.0        6.0       9.0      14.4  0.0
# 2             0               0    10.0        6.0       9.7      15.6  0.0
# 3             0               0    10.0        6.0       9.6      15.5  0.0
# 4             0               0    10.0        6.0      10.3      16.5  0.0
#
# [5 rows x 34 columns]

# %% [markdown]
# ### Задача 4
#
# Сохраните DataFrame из предыдущей задачи в файл `result.csv`. В качестве названия столбца-индекса используйте `index`.

# %%
df.to_csv('result.csv', index_label='index')

# %% [markdown]
# ### Задача 5
#
# Загрузите содержимое SQL-таблицы `ratings` в DataFrame. Выведите первые пять строк DataFrame на экран. Для подключения к БД используйте строку подключения, указанную в следующей ячейке.

# %%
import sqlalchemy
import psycopg2

# %%
connection = 'postgresql+psycopg2://readonly:6hajV34RTQfmxhS@dsstudents.skillbox.ru:5433/db_ds_students'
engine = sqlalchemy.create_engine(connection)
connect = engine.connect()

# %%
inspector = sqlalchemy.inspect(engine)
inspector.get_table_names()
# Out:
# ['links',
#  'joi',
#  'mobile',
#  'new_table',
#  'course_purchases',
#  'orders',
#  'sales',
#  'exploratory',
#  'studentt',
#  'superheroes',
#  'users',
#  'product_types',
#  'products',
#  'ratings',
#  'keywords',
#  'course_purchases_1']

# %%
df = pd.read_sql("select * from ratings", connect)
df.head()
# Out:
#    userid  movieid  rating   timestamp
# 0    1156     8636     3.5  1360517845
# 1    1156     8644     2.0  1449686473
# 2    1156     8665     5.0  1449424308
# 3    1156     8957     1.0  1450027368
# 4    1156     8961     4.5  1360517493

# %% [markdown]
# ### Задача 6
#
# Сохраните первые 10000 записей датафрейма из предыдущей задачи в файл `result2.xlsx`, при сохранении задайте листу имя `MySheet`.
#
# (Примечание: для указания имени листа в файле Excel как при чтении, так и при записи используется параметр `sheet_name`)

# %%
df = pd.read_sql("select * from ratings limit 10000", connect)

# %%
df.to_excel('result2.xlsx', sheet_name='MySheet')

# %% [markdown]
# ### Задача 7
#
# Определите количество документов в коллекции `users` в MongoDB. Если количество документов < 1000, то в следующей ячейке загрузите всё содержимое этой коллекции в список и выведите нулевой элемент этого списка на экран. Для подключения к MongoDB используйте строку подключения, указанную в следующей ячейке.

# %%
import pymongo
from pymongo import MongoClient

# %%
conn = 'mongodb://students:X63673t47Gl03Sq@dsstudents.skillbox.ru:27017/?authSource=movies'
Client = MongoClient()
connect = pymongo.MongoClient(conn)

# %%
db = connect['movies']

# %%
db.list_collection_names()
# Out:
# ['tags', 'users']

# %%
users = db['users']

# %%
users.find_one()
# Out:
# {'_id': ObjectId('5cc69095067496679c74f7a4'),
#  'user_id': 'ed5da480-57a2-489c-8e68-512155ab9892',
#  'first_name': 'Жанна',
#  'last_name': 'Петрова',
#  'mail': 'zhanna_03816@gmail.com',
#  'age': 20.0}

# %%
users.count_documents({})
# Out:
# 100

# %%
head = users.find()
my_list = list(head)
my_list

# %% [markdown]
# ### Задача 8
#
# Преобразуйте список всех документов коллекции `users` из предыдущей задачи в pandas DataFrame и сохраните его содержимое в файл `result3.xlsx`.

# %%
import pandas as pd

# %%
df = pd.DataFrame(my_list)
df
# Out:
#                          _id                               user_id first_name  \
# 0   5cc69095067496679c74f7a4  ed5da480-57a2-489c-8e68-512155ab9892      Жанна
# 1   5cc690e2067496679c74f7a5  7ba07e70-f76a-4bbc-9b5d-34265f4f7638     Андрей
# 2   5cc690e2067496679c74f7a6  8b1752da-599d-413a-a2e9-bc75387b2be9    Евгения
# 3   5cc690e2067496679c74f7a7  3e3b7b84-65f0-4152-815a-730bec31bb9d   Василиса
# 4   5cc690e2067496679c74f7a8  8c390b6e-a490-44ac-b974-f5dec7f6970b      Наина
# ..                       ...                                   ...        ...
# 95  5cc690e2067496679c74f804  395ab5c0-e2f1-4644-974e-29fa4f821b0e  Прасковья
# 96  5cc690e2067496679c74f7fc  f14b8666-5fd4-4acc-9d77-50df48fcd050       Нина
# 97  5cc690e2067496679c74f806  9fc78a49-22bc-4c21-9ee7-1444030c371a  Маргарита
# 98  5cc690e2067496679c74f807  3e585c7d-52f7-4718-a324-71a5fec75a47   Ангелина
# 99  5cc690e2067496679c74f805  1b681fe4-5c5a-4c60-b0a3-24241374df95   Аристарх
#
#      last_name                          mail   age
# 0      Петрова        zhanna_03816@gmail.com  20.0
# 1     Белоусов           andrej_23624@ivi.ru  18.0
# 2   Дементьева    evgenija_22008@skillbox.ru  18.0
# 3     Семенова         vasilisa_42757@ivi.ru  18.0
# 4    Горбунова            naina_95710@ivi.ru  19.0
# ..         ...                           ...   ...
# 95   Селезнева   praskovja_16895@skillbox.ru  20.0
# 96   Алексеева          nina_61823@yandex.ru  17.0
# 97    Кабанова  margarita.kabanova@yandex.ru  19.0
# 98    Денисова     angelina.denisova@mail.ru  20.0
# 99    Селезнев                5065073@ivi.ru  27.0
#
# [100 rows x 6 columns]

# %%
df.to_excel("result3.xlsx")

# %% [markdown]
# ## Дополнительные (необязательные) задачи
#
# ### Задача 9
#
# Используя данные SQL-таблицы `ratings`, для каждого пользователя (столбец `userid`) определите средний рейтинг, который этот пользователь поставил фильмам. Результат выведите на экран.
#
# Группировку проведите двумя способами: с помощью `GROUP BY` в строке запроса к БД и с использованием метода `groupby` в pandas.
#
# Для подключения к БД используйте строку подключения в следующей ячейке

# %%
import pandas as pd
import sqlalchemy
import psycopg2

# %%
conn = 'postgresql+psycopg2://readonly:6hajV34RTQfmxhS@dsstudents.skillbox.ru:5433/db_ds_students'
engine = sqlalchemy.create_engine(conn)
connect = engine.connect()

# %%
df = pd.read_sql("select * from ratings", connect)
df.head()
# Out:
# Exception during reset or similar
# Traceback (most recent call last):
#   File "C:\Users\andrey\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 986, in _finalize_fairy
#     fairy._reset(
#   File "C:\Users\andrey\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py", line 1432, in _reset
#     pool._dialect.do_rollback(self)
#   File "C:\Users\andrey\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py", line 698, in do_rollback
#     dbapi_connection.rollback()
# psycopg2.OperationalError: server closed the connection unexpectedly
# 	This probably means the server terminated abnormally
# 	before or while processing the request.
#    userid  movieid  rating   timestamp
# 0    1250    40819     4.5  1223263858
# 1    1250    41226     4.0  1268944042
# 2    1250    41566     4.5  1223348857
# 3    1250    41569     0.5  1225771313
# 4    1250    41769     4.0  1223349494

# %%
df1 = pd.read_sql("select userid, avg(rating) as avg_rating from ratings group by userid", connect)
df1
# Out:
#       userid  avg_rating
# 0       6114    4.000000
# 1       4790    4.000000
# 2        273    4.314685
# 3       3936    3.756757
# 4       5761    3.419220
# ...      ...         ...
# 7951    4827    2.828025
# 7952    7227    3.950000
# 7953     790    3.918605
# 7954    5642    4.026786
# 7955    2850    3.468750
#
# [7956 rows x 2 columns]

# %%
df1.groupby('userid')

# %% [markdown]
# ### Задача 10
#
# Объедините таблицы `ratings` и `keywords` по столбцам `movieid` (используйте левое объединение). Объединение проведите двумя способами: с помощью `LEFT JOIN` в строке запроса к БД и с использованием метода `merge` в pandas. Результат объединения загрузите в DataFrame и сохраните в файл `result4.csv`.
#
# Обратите внимание, что при объединении возможно дублирование столбцов. В результирующем датафрейме не должно быть таких дублированных столбцов.

# %%
import pandas as pd
import sqlalchemy
import psycopg2

# %%
conn = 'postgresql+psycopg2://readonly:6hajV34RTQfmxhS@dsstudents.skillbox.ru:5433/db_ds_students'
engine = sqlalchemy.create_engine(conn)
connect = engine.connect()

# %%
inspector = sqlalchemy.inspect(engine)
inspector.get_table_names()
# Out:
# ['links',
#  'joi',
#  'mobile',
#  'new_table',
#  'course_purchases',
#  'orders',
#  'sales',
#  'exploratory',
#  'studentt',
#  'superheroes',
#  'users',
#  'product_types',
#  'products',
#  'ratings',
#  'keywords',
#  'course_purchases_1']

# %% [markdown]
# Способ №1:
# df = pd.read_sql('SELECT ratings.userid, ratings.movieid, ratings.rating, ratings.timestamp, keywords.tags FROM ratings LEFT JOIN keywords ON ratings.movieid = keywords.movieid;', connect)
# df.head(7)

# %%
df1 = pd.read_sql('SELECT * FROM ratings', connect)
df1.head()
# Out:
#    userid  movieid  rating  timestamp
# 0    5624     1653     4.0  972948907
# 1    5624     1676     4.0  972948907
# 2    5624     1748     4.0  972948866
# 3    5624     1876     3.0  972949018
# 4    5624     1909     4.0  972948976

# %%
df2 = pd.read_sql('SELECT * FROM keywords', connect)
df2.head()
# Out:
#    movieid                                               tags
# 0      862  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1     8844  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2    15602  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3    31357  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4    11862  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...

# %%
df = df1.merge(df2, how='left')
df.head()
# Out:
#    userid  movieid  rating  timestamp  \
# 0    5624     1653     4.0  972948907
# 1    5624     1653     4.0  972948907
# 2    5624     1676     4.0  972948907
# 3    5624     1676     4.0  972948907
# 4    5624     1748     4.0  972948866
#
#                                                 tags
# 0  [{'id': 983, 'name': 'brazilian'}, {'id': 2020...
# 1  [{'id': 983, 'name': 'brazilian'}, {'id': 2020...
# 2  [{'id': 1822, 'name': 'bath'}, {'id': 2673, 'n...
# 3  [{'id': 1822, 'name': 'bath'}, {'id': 2673, 'n...
# 4                                                NaN

# %%
df.to_csv('result4.csv')
df = pd.read_csv('result4.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  userid  movieid  rating   timestamp  \
# 0           0    1250    40819     4.5  1223263858
# 1           1    1250    40819     4.5  1223263858
# 2           2    1250    41226     4.0  1268944042
# 3           3    1250    41566     4.5  1223348857
# 4           4    1250    41566     4.5  1223348857
#
#                                                 tags
# 0                                                 []
# 1                                                 []
# 2                                                NaN
# 3  [{'id': 242, 'name': 'new york'}, {'id': 4470,...
# 4  [{'id': 242, 'name': 'new york'}, {'id': 4470,...

# %% [markdown]
# ### Задача 11
#
# Используя объединенную таблицу из предыдущего задания, найдите все идентификаторы фильмов с тегом `africa` (но не `south africa` или любые другие). Список тегов в формате JSON записан в столбце `tags`.

# %%
import pandas as pd
import sqlalchemy
import psycopg2

# %%
conn = 'postgresql+psycopg2://readonly:6hajV34RTQfmxhS@dsstudents.skillbox.ru:5433/db_ds_students'
engine = sqlalchemy.create_engine(conn)
connect = engine.connect()

# %%
inspector = sqlalchemy.inspect(engine)
inspector.get_table_names()
# Out:
# ['links',
#  'joi',
#  'mobile',
#  'new_table',
#  'course_purchases',
#  'orders',
#  'sales',
#  'exploratory',
#  'studentt',
#  'superheroes',
#  'users',
#  'product_types',
#  'products',
#  'ratings',
#  'keywords',
#  'course_purchases_1']

# %%
df = pd.read_sql("select * from keywords", connect)
df.head(10)
# Out:
#    movieid                                               tags
# 0      862  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1     8844  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2    15602  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3    31357  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4    11862  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...
# 5      949  [{'id': 642, 'name': 'robbery'}, {'id': 703, '...
# 6    11860  [{'id': 90, 'name': 'paris'}, {'id': 380, 'nam...
# 7    45325                                                 []
# 8     9091  [{'id': 949, 'name': 'terrorist'}, {'id': 1562...
# 9      710  [{'id': 701, 'name': 'cuba'}, {'id': 769, 'nam...

# %%
df2 = df['tags']
df2.head()
# Out:
# 0    [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1    [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2    [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3    [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4    [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...
# Name: tags, dtype: object

# %%
my_list = list(df2)
my_list
# Out:
# ["[{'id': 931, 'name': 'jealousy'}, {'id': 4290, 'name': 'toy'}, {'id': 5202, 'name': 'boy'}, {'id': 6054, 'name': 'friendship'}, {'id': 9713, 'name': 'friends'}, {'id': 9823, 'name': 'rivalry'}, {'id': 165503, 'name': 'boy next door'}, {'id': 170722, 'name': 'new toy'}, {'id': 187065, 'name': 'toy comes to life'}]",
#  '[{\'id\': 10090, \'name\': \'board game\'}, {\'id\': 10941, \'name\': \'disappearance\'}, {\'id\': 15101, \'name\': "based on children\'s book"}, {\'id\': 33467, \'name\': \'new home\'}, {\'id\': 158086, \'name\': \'recluse\'}, {\'id\': 158091, \'name\': \'giant insect\'}]',
#  "[{'id': 1495, 'name': 'fishing'}, {'id': 12392, 'name': 'best friend'}, {'id': 179431, 'name': 'duringcreditsstinger'}, {'id': 208510, 'name': 'old men'}]",
#  "[{'id': 818, 'name': 'based on novel'}, {'id': 10131, 'name': 'interracial relationship'}, {'id': 14768, 'name': 'single mother'}, {'id': 15160, 'name': 'divorce'}, {'id': 33455, 'name': 'chick flick'}]",
#  "[{'id': 1009, 'name': 'baby'}, {'id': 1599, 'name': 'midlife crisis'}, {'id': 2246, 'name': 'confidence'}, {'id': 4995, 'name': 'aging'}, {'id': 5600, 'name': 'daughter'}, {'id': 10707, 'name': 'mother daughter relationship'}, {'id': 13149, 'name': 'pregnancy'}, {'id': 33358, 'name': 'contraception'}, {'id': 170521, 'name': 'gynecologist'}]",
#  "[{'id': 642, 'name': 'robbery'}, {'id': 703, 'name': 'detective'}, {'id': 974, 'name': 'bank'}, {'id': 1523, 'name': 'obsession'}, {'id': 3713, 'name': 'chase'}, {'id': 7281, 'name': 'shooting'}, {'id': 9727, 'name': 'thief'}, {'id': 9812, 'name': 'honor'}, {'id': 9826, 'name': 'murder'}, {'id': 9937, 'name': 'suspense'}, {'id': 10051, 'name': 'heist'}, {'id': 10085, 'name': 'betrayal'}, {'id': 10594, 'name': 'money'}, {'id': 10726, 'name': 'gang'}, {'id': 15076, 'name': 'cat and mouse'}, {'id': 18023, 'name': 'criminal mastermind'}, {'id': 34117, 'name': 'cult film'}, {'id': 156121, 'name': 'ex-con'}, {'id': 159343, 'name': 'heist movie'}, {'id': 159434, 'name': 'one last job'}, {'id': 167104, 'name': 'loner'}, {'id': 192261, 'name': 'bank job'}, {'id': 207268, 'name': 'neo-noir'}, {'id': 208009, 'name': 'gun fight'}, {'id': 214983, 'name': 'crime epic'}]",
#  "[{'id': 90, 'name': 'paris'}, {'id': 380, 'name': 'brother brother relationship'}, {'id': 2072, 'name': 'chauffeur'}, {'id': 9398, 'name': 'long island'}, {'id': 9492, 'name': 'fusion'}, {'id': 33626, 'name': 'millionaire'}]",
#  '[]',
#  "[{'id': 949, 'name': 'terrorist'}, {'id': 1562, 'name': 'hostage'}, {'id': 1653, 'name': 'explosive'}, {'id': 193533, 'name': 'vice president'}]",
#  "[{'id': 701, 'name': 'cuba'}, {'id': 769, 'name': 'falsely accused'}, {'id': 1308, 'name': 'secret identity'}, {'id': 2812, 'name': 'computer virus'}, {'id': 3268, 'name': 'secret base'}, {'id': 3272, 'name': 'secret intelligence service'}, {'id': 3278, 'name': 'kgb'}, {'id': 3376, 'name': 'satellite'}, {'id': 3531, 'name': 'special car'}, {'id': 3560, 'name': 'cossack'}, {'id': 3561, 'name': 'electromagnetic pulse'}, {'id': 3562, 'name': 'time bomb'}, {'id': 3563, 'name': 'st. petersburg russia'}, {'id': 3564, 'name': 'ejection seat'}, {'id': 193008, 'name': 'red army'}]",
#  "[{'id': 833, 'name': 'white house'}, {'id': 840, 'name': 'usa president'}, {'id': 1605, 'name': 'new love'}, {'id': 33476, 'name': 'widower'}, {'id': 211505, 'name': 'wildlife conservation'}]",
#  "[{'id': 3633, 'name': 'dracula'}, {'id': 11931, 'name': 'spoof'}]",
#  "[{'id': 1994, 'name': 'wolf'}, {'id': 6411, 'name': 'dog-sledding race'}, {'id': 9880, 'name': 'alaska'}, {'id': 15162, 'name': 'dog'}, {'id': 15169, 'name': 'goose'}, {'id': 158175, 'name': 'bear attack'}, {'id': 158370, 'name': 'dog sled'}, {'id': 158371, 'name': 'frozen lake'}]",
#  "[{'id': 840, 'name': 'usa president'}, {'id': 2946, 'name': 'presidential election'}, {'id': 4240, 'name': 'watergate scandal'}, {'id': 5565, 'name': 'biography'}, {'id': 6086, 'name': 'government'}, {'id': 6165, 'name': 'historical figure'}]",
#  "[{'id': 911, 'name': 'exotic island'}, {'id': 1454, 'name': 'treasure'}, {'id': 1969, 'name': 'map'}, {'id': 3799, 'name': 'ship'}, {'id': 5470, 'name': 'scalp'}, {'id': 12988, 'name': 'pirate'}]",
#  "[{'id': 383, 'name': 'poker'}, {'id': 726, 'name': 'drug abuse'}, {'id': 1228, 'name': '1970s'}, {'id': 2635, 'name': 'overdose'}, {'id': 33625, 'name': 'illegal prostitution'}]",
#  "[{'id': 420, 'name': 'bowling'}, {'id': 818, 'name': 'based on novel'}, {'id': 964, 'name': 'servant'}, {'id': 2755, 'name': 'country life'}, {'id': 7564, 'name': 'jane austen'}, {'id': 10911, 'name': 'inheritance'}, {'id': 11109, 'name': 'military officer'}, {'id': 15060, 'name': 'period drama'}, {'id': 156507, 'name': 'rainstorm'}, {'id': 156510, 'name': 'horse and carriage'}, {'id': 156512, 'name': 'decorum'}]",
#  '[{\'id\': 612, \'name\': \'hotel\'}, {\'id\': 613, \'name\': "new year\'s eve"}, {\'id\': 616, \'name\': \'witch\'}, {\'id\': 622, \'name\': \'bet\'}, {\'id\': 922, \'name\': \'hotel room\'}, {\'id\': 2700, \'name\': \'sperm\'}, {\'id\': 12670, \'name\': \'los angeles\'}, {\'id\': 160488, \'name\': \'hoodlum\'}, {\'id\': 187056, \'name\': \'woman director\'}, {\'id\': 198129, \'name\': \'episode film\'}]',
#  "[{'id': 409, 'name': 'africa'}, {'id': 1551, 'name': 'indigenous'}, {'id': 2526, 'name': 'human animal relationship'}, {'id': 5155, 'name': 'bat'}]",
#  "[{'id': 380, 'name': 'brother brother relationship'}, {'id': 1552, 'name': 'subway'}, {'id': 14512, 'name': 'new york city'}, {'id': 155735, 'name': 'new york subway'}, {'id': 156120, 'name': 'train robbery'}]",
#  "[{'id': 395, 'name': 'gambling'}, {'id': 416, 'name': 'miami'}, {'id': 818, 'name': 'based on novel'}, {'id': 8438, 'name': 'job'}, {'id': 9826, 'name': 'murder'}, {'id': 9935, 'name': 'travel'}, {'id': 10391, 'name': 'mafia'}, {'id': 10594, 'name': 'money'}, {'id': 11061, 'name': 'debt'}, {'id': 11578, 'name': 'mobster'}, {'id': 12094, 'name': 'business'}, {'id': 12396, 'name': 'hollywood'}, {'id': 13142, 'name': 'gangster'}, {'id': 14536, 'name': 'crime'}, {'id': 14819, 'name': 'violence'}, {'id': 14964, 'name': 'drug'}, {'id': 33879, 'name': 'producer'}, {'id': 159608, 'name': 'con'}]",
#  "[{'id': 796, 'name': 'police brutality'}, {'id': 2800, 'name': 'psychology'}, {'id': 4668, 'name': 'police operation'}, {'id': 5430, 'name': 'police protection'}, {'id': 10714, 'name': 'serial killer'}, {'id': 11268, 'name': 'psychologist'}, {'id': 13001, 'name': 'cowardliness'}]",
#  "[{'id': 271, 'name': 'competition'}, {'id': 441, 'name': 'assassination'}, {'id': 591, 'name': 'cia'}, {'id': 974, 'name': 'bank'}, {'id': 977, 'name': 'cat'}, {'id': 1666, 'name': 'mexican standoff'}, {'id': 2350, 'name': 'seattle'}, {'id': 2708, 'name': 'hitman'}, {'id': 3045, 'name': 'mission of murder'}, {'id': 3979, 'name': 'hidden camera'}, {'id': 9823, 'name': 'rivalry'}, {'id': 10084, 'name': 'rescue'}, {'id': 10950, 'name': 'shootout'}, {'id': 11148, 'name': 'police chase'}, {'id': 12355, 'name': 'sniper rifle'}, {'id': 18107, 'name': 'silencer'}, {'id': 33456, 'name': 'double cross'}, {'id': 167861, 'name': 'caribbean'}, {'id': 178929, 'name': 'detroit michigan'}]",
#  "[{'id': 10624, 'name': 'bully'}]",
#  "[{'id': 312, 'name': 'man vs machine'}, {'id': 10158, 'name': 'alien planet'}, {'id': 15354, 'name': 'struggle for survival'}]",
#  '[]',
#  "[{'id': 7345, 'name': 'dead animal'}, {'id': 11325, 'name': 'shot to death'}, {'id': 18068, 'name': 'teenage boy'}, {'id': 18320, 'name': 'held at gunpoint'}, {'id': 41355, 'name': 'teacher student relationship'}, {'id': 163531, 'name': 'albino'}, {'id': 163533, 'name': 'fainting'}, {'id': 163534, 'name': 'jacobs ladder'}, {'id': 163540, 'name': 'christ allegory'}, {'id': 163543, 'name': 'psionic power'}, {'id': 163545, 'name': 'healing power'}, {'id': 163552, 'name': 'looking pale'}, {'id': 163553, 'name': 'flickering light'}, {'id': 163558, 'name': 'extrasensory perception'}]",
#  "[{'id': 30, 'name': 'individual'}, {'id': 549, 'name': 'prostitute'}, {'id': 567, 'name': 'alcohol'}, {'id': 585, 'name': 'casino'}, {'id': 699, 'name': 'love at first sight'}, {'id': 725, 'name': 'lovesickness'}, {'id': 887, 'name': 'film producer'}, {'id': 888, 'name': 'screenwriter'}, {'id': 922, 'name': 'hotel room'}, {'id': 3737, 'name': 'dying and death'}, {'id': 3927, 'name': 'rage and hate'}, {'id': 6059, 'name': 'unsociability'}, {'id': 7464, 'name': 'alcoholism'}, {'id': 12670, 'name': 'los angeles'}, {'id': 15237, 'name': 'alcohol abuse'}, {'id': 155793, 'name': 'attempted suicide'}]",
#  "[{'id': 497, 'name': 'shakespeare'}, {'id': 931, 'name': 'jealousy'}, {'id': 9713, 'name': 'friends'}, {'id': 17982, 'name': 'moor'}]",
#  "[{'id': 1228, 'name': '1970s'}, {'id': 5248, 'name': 'female friendship'}, {'id': 10683, 'name': 'coming of age'}, {'id': 170521, 'name': 'gynecologist'}, {'id': 170533, 'name': 'photocopier'}, {'id': 170539, 'name': 'truth or dare'}, {'id': 187056, 'name': 'woman director'}]",
#  "[{'id': 1316, 'name': 'captain'}, {'id': 33384, 'name': 'napoleonic wars'}, {'id': 33386, 'name': 'old flame'}, {'id': 33388, 'name': 'admiral'}]",
#  "[{'id': 402, 'name': 'clone'}, {'id': 1566, 'name': 'dream'}, {'id': 2041, 'name': 'island'}, {'id': 4484, 'name': 'eye'}, {'id': 4565, 'name': 'dystopia'}, {'id': 4995, 'name': 'aging'}, {'id': 6054, 'name': 'friendship'}, {'id': 10084, 'name': 'rescue'}, {'id': 10103, 'name': 'children'}, {'id': 14659, 'name': 'girl'}, {'id': 157955, 'name': 'childhood'}]",
#  "[{'id': 964, 'name': 'servant'}, {'id': 2311, 'name': 'cabaret'}, {'id': 2682, 'name': 'shanghai'}, {'id': 2992, 'name': 'diva'}, {'id': 6464, 'name': 'uncle'}, {'id': 11869, 'name': 'mistress'}, {'id': 41277, 'name': 'umbrella'}]",
#  "[{'id': 897, 'name': 'rap music'}, {'id': 3436, 'name': 'karate'}, {'id': 6270, 'name': 'high school'}, {'id': 6610, 'name': 'naval officer'}, {'id': 10508, 'name': 'teacher'}, {'id': 155582, 'name': 'amusement park'}]",
#  "[{'id': 222, 'name': 'schizophrenia'}, {'id': 276, 'name': 'philadelphia'}, {'id': 277, 'name': 'cassandra syndrom'}, {'id': 278, 'name': 'stockholm syndrome'}, {'id': 4379, 'name': 'time travel'}, {'id': 4458, 'name': 'post-apocalyptic'}, {'id': 4565, 'name': 'dystopia'}, {'id': 14675, 'name': 'lethal virus'}, {'id': 15149, 'name': 'monkey'}, {'id': 162801, 'name': 'subterranean'}]",
#  '[]',
#  "[{'id': 3020, 'name': 'sheep'}, {'id': 4931, 'name': 'pig'}, {'id': 5608, 'name': 'affection'}, {'id': 8082, 'name': 'piglet'}, {'id': 11115, 'name': 'heroism'}, {'id': 11477, 'name': 'talking animal'}, {'id': 18013, 'name': 'separation'}, {'id': 33671, 'name': 'german shepherd'}, {'id': 158019, 'name': 'grandson'}, {'id': 206052, 'name': 'talking pig'}]",
#  "[{'id': 392, 'name': 'england'}, {'id': 437, 'name': 'painter'}, {'id': 8997, 'name': 'conscientious objector'}, {'id': 10183, 'name': 'independent film'}, {'id': 13065, 'name': 'soldier'}]",
#  "[{'id': 378, 'name': 'prison'}, {'id': 570, 'name': 'rape'}, {'id': 1952, 'name': 'socially deprived family'}, {'id': 2060, 'name': 'penalty'}, {'id': 2122, 'name': 'death penalty'}, {'id': 2300, 'name': 'despair'}, {'id': 2501, 'name': 'death row'}, {'id': 2538, 'name': 'begnadigung'}, {'id': 2726, 'name': 'therapist'}, {'id': 2796, 'name': 'self-discovery'}, {'id': 2885, 'name': 'prison cell'}, {'id': 3012, 'name': 'court case'}, {'id': 3437, 'name': 'death sentence'}, {'id': 3440, 'name': 'doomed man'}, {'id': 3441, 'name': 'sentence'}, {'id': 3442, 'name': 'lethal injection'}, {'id': 3446, 'name': 'forgiveness'}, {'id': 3447, 'name': 'charity'}, {'id': 3448, 'name': 'mercy petition'}, {'id': 3927, 'name': 'rage and hate'}, {'id': 6059, 'name': 'unsociability'}, {'id': 6145, 'name': 'right and justice'}, {'id': 6148, 'name': 'court'}, {'id': 11263, 'name': 'electric chair'}, {'id': 13001, 'name': 'cowardliness'}]",
#  '[]',
#  "[{'id': 13014, 'name': 'orphan'}, {'id': 204353, 'name': 'identical twin'}]",
#  "[{'id': 1525, 'name': 'puberty'}, {'id': 6270, 'name': 'high school'}, {'id': 6664, 'name': 'make a match'}, {'id': 7208, 'name': 'spoiled child'}, {'id': 10199, 'name': 'gay interest'}, {'id': 11933, 'name': 'conflict'}, {'id': 187056, 'name': 'woman director'}]",
#  "[{'id': 3644, 'name': 'south africa'}]",
#  "[{'id': 392, 'name': 'england'}, {'id': 497, 'name': 'shakespeare'}, {'id': 1930, 'name': 'kidnapping'}, {'id': 9826, 'name': 'murder'}, {'id': 13084, 'name': 'king'}]",
#  "[{'id': 10594, 'name': 'money'}, {'id': 11254, 'name': 'loss of virginity'}, {'id': 159640, 'name': 'hiding in a dumpster'}, {'id': 159643, 'name': 'mercy killing'}, {'id': 159660, 'name': 'armored truck'}, {'id': 159661, 'name': 'crushed by a car'}]",
#  "[{'id': 931, 'name': 'jealousy'}, {'id': 1279, 'name': 'medicine'}, {'id': 2098, 'name': 'fountain'}, {'id': 6148, 'name': 'court'}, {'id': 10329, 'name': 'wealth'}, {'id': 44448, 'name': 'spaniel'}, {'id': 44449, 'name': 'gloves'}]",
#  "[{'id': 779, 'name': 'martial arts'}, {'id': 1299, 'name': 'monster'}, {'id': 2041, 'name': 'island'}, {'id': 10292, 'name': 'gore'}, {'id': 10821, 'name': 'sorcerer'}, {'id': 12380, 'name': 'tournament'}, {'id': 14819, 'name': 'violence'}, {'id': 41645, 'name': 'based on video game'}, {'id': 188955, 'name': 'hand to hand combat'}]",
#  "[{'id': 596, 'name': 'adultery'}, {'id': 1442, 'name': 'winter'}, {'id': 1523, 'name': 'obsession'}, {'id': 2136, 'name': 'television'}, {'id': 6018, 'name': 'new hampshire'}, {'id': 208477, 'name': 'narcissistic personality disorder'}]",
#  "[{'id': 1334, 'name': 'wedding vows'}, {'id': 1459, 'name': 'marriage proposal'}, {'id': 2587, 'name': 'married couple'}, {'id': 5773, 'name': 'monogamy'}, {'id': 5999, 'name': 'advice'}, {'id': 6038, 'name': 'marriage'}, {'id': 9470, 'name': 'quilt'}, {'id': 9673, 'name': 'love'}, {'id': 33694, 'name': 'family holiday'}, {'id': 34094, 'name': 'extramarital affair'}, {'id': 164039, 'name': 'grandmother'}, {'id': 187056, 'name': 'woman director'}]",
#  "[{'id': 476, 'name': 'self-fulfilling prophecy'}, {'id': 703, 'name': 'detective'}, {'id': 1470, 'name': 's.w.a.t.'}, {'id': 2231, 'name': 'drug dealer'}, {'id': 3597, 'name': 'evisceration'}, {'id': 3857, 'name': 'lust and impulsiveness'}, {'id': 3927, 'name': 'rage and hate'}, {'id': 3932, 'name': 'pride and vanity'}, {'id': 4138, 'name': 'immoderateness'}, {'id': 4142, 'name': 'insomnia'}, {'id': 5340, 'name': 'investigation'}, {'id': 6125, 'name': 'pension'}, {'id': 6149, 'name': 'police'}, {'id': 10714, 'name': 'serial killer'}]",
#  '[]',
#  "[{'id': 393, 'name': 'civil war'}]",
#  "[{'id': 1463, 'name': 'culture clash'}, {'id': 3591, 'name': 'settler'}, {'id': 3691, 'name': 'forbidden love'}, {'id': 4090, 'name': 'colony'}, {'id': 4344, 'name': 'musical'}, {'id': 4542, 'name': 'gold rush'}, {'id': 7376, 'name': 'princess'}, {'id': 9840, 'name': 'romance'}, {'id': 10322, 'name': 'native american'}, {'id': 10336, 'name': 'animation'}, {'id': 160977, 'name': 'virginia'}, {'id': 165086, 'name': 'star crossed lovers'}, {'id': 173808, 'name': 'reference to pizarro'}, {'id': 173811, 'name': 'jamestown virginia'}, {'id': 173815, 'name': 'pug dog'}, {'id': 173823, 'name': 'cross cultural relationship'}, {'id': 173824, 'name': 'musket'}, {'id': 173825, 'name': 'animate tree'}, {'id': 180217, 'name': 'indian chief'}, {'id': 185343, 'name': 'based on myths or folklore'}, {'id': 207941, 'name': '17th century'}, {'id': 208426, 'name': 'shamanism'}, {'id': 225547, 'name': 'songs'}, {'id': 230456, 'name': 'indians vs. settlers'}, {'id': 234183, 'name': 'animal sidekick'}, {'id': 234184, 'name': 'powhatan'}, {'id': 234185, 'name': 'land claim'}]",
#  "[{'id': 1992, 'name': 'professor'}, {'id': 158718, 'name': 'lgbt'}, {'id': 187056, 'name': 'woman director'}]",
#  "[{'id': 3703, 'name': 'law'}, {'id': 5493, 'name': 'relatives'}, {'id': 14604, 'name': 'theft'}, {'id': 15009, 'name': 'criminal'}, {'id': 18023, 'name': 'criminal mastermind'}, {'id': 18024, 'name': 'hungarian'}, {'id': 18027, 'name': 'sibling'}]",
#  '[]',
#  "[{'id': 549, 'name': 'prostitute'}, {'id': 2393, 'name': 'adoption'}, {'id': 4130, 'name': 'adoptive father'}, {'id': 5885, 'name': 'childlessness'}, {'id': 6230, 'name': 'looking for  birth parents'}, {'id': 8018, 'name': 'adoptive mother'}, {'id': 10183, 'name': 'independent film'}, {'id': 33625, 'name': 'illegal prostitution'}, {'id': 208349, 'name': 'child'}]",
#  "[{'id': 10183, 'name': 'independent film'}]",
#  "[{'id': 6075, 'name': 'sport'}, {'id': 9963, 'name': 'kids and family'}, {'id': 13042, 'name': 'soccer'}, {'id': 187056, 'name': 'woman director'}]",
#  "[{'id': 567, 'name': 'alcohol'}, {'id': 2679, 'name': 'artist'}, {'id': 6027, 'name': 'music'}, {'id': 14964, 'name': 'drug'}, {'id': 33624, 'name': 'band'}]",
#  '[]',
#  "[{'id': 2672, 'name': 'baltimore'}, {'id': 4543, 'name': 'thanksgiving'}, {'id': 7629, 'name': 'family clan'}, {'id': 155294, 'name': 'family conflict'}, {'id': 171760, 'name': 'generations conflict'}, {'id': 187056, 'name': 'woman director'}]",
#  "[{'id': 2041, 'name': 'island'}, {'id': 3344, 'name': 'letter'}, {'id': 4461, 'name': 'postman'}, {'id': 5420, 'name': 'fisherman'}, {'id': 5933, 'name': 'poet'}]",
#  '[]',
#  "[{'id': 1990, 'name': 'cupboard'}, {'id': 6186, 'name': 'games'}, {'id': 6300, 'name': 'puppet'}, {'id': 33465, 'name': 'parallel world'}, {'id': 187065, 'name': 'toy comes to life'}]",
#  "[{'id': 570, 'name': 'rape'}, {'id': 1419, 'name': 'gun'}, {'id': 2801, 'name': 'self-defense'}, {'id': 204959, 'name': 'grieving parents'}]",
#  "[{'id': 1233, 'name': 'composer'}, {'id': 1310, 'name': 'mentor'}, {'id': 1635, 'name': 'deaf-mute'}, {'id': 4344, 'name': 'musical'}, {'id': 4488, 'name': 'apprentice'}, {'id': 5289, 'name': 'private life'}, {'id': 6027, 'name': 'music'}, {'id': 158558, 'name': 'disabled'}]",
#  "[{'id': 248, 'name': 'date'}, {'id': 398, 'name': 'slang'}, {'id': 898, 'name': 'hip-hop'}, {'id': 4438, 'name': 'cousin'}, {'id': 9755, 'name': 'parody'}, {'id': 10700, 'name': 'hood'}, {'id': 10726, 'name': 'gang'}, {'id': 11514, 'name': 'social satire'}, {'id': 12425, 'name': 'racism'}, {'id': 13142, 'name': 'gangster'}]",
#  "[{'id': 2041, 'name': 'island'}, {'id': 5918, 'name': 'painting'}, {'id': 9727, 'name': 'thief'}, {'id': 167868, 'name': 'seasickness'}]",
#  "[{'id': 4166, 'name': 'biotope'}, {'id': 4459, 'name': 'vegetarian'}, {'id': 6305, 'name': 'pollution'}]",
#  "[{'id': 2157, 'name': 'hacker'}, {'id': 4563, 'name': 'virtual reality'}, {'id': 6104, 'name': 'computer'}, {'id': 9725, 'name': 'sword fight'}]",
#  '[]',
#  "[{'id': 128, 'name': 'love triangle'}, {'id': 2335, 'name': 'southern france'}, {'id': 2918, 'name': 'estate agent'}, {'id': 3190, 'name': 'menage a trois'}, {'id': 4580, 'name': 'van'}, {'id': 187056, 'name': 'woman director'}]",
#  "[{'id': 897, 'name': 'rap music'}, {'id': 970, 'name': 'parent child relationship'}, {'id': 4562, 'name': 'rapper'}, {'id': 8438, 'name': 'job'}]",
#  "[{'id': 246, 'name': 'dancing'}, {'id': 380, 'name': 'brother brother relationship'}, {'id': 459, 'name': 'sexual obsession'}, {'id': 797, 'name': 'showdown'}, {'id': 798, 'name': 'sheriff'}, {'id': 1664, 'name': 'eroticism'}, {'id': 2483, 'name': 'nudity'}, {'id': 2492, 'name': 'bank robber'}, {'id': 3133, 'name': 'vampire'}, {'id': 3649, 'name': 'holy water'}, {'id': 4063, 'name': 'siege'}, {'id': 6593, 'name': 'stripper'}, {'id': 10093, 'name': 'priest'}, {'id': 14601, 'name': 'explosion'}, {'id': 14687, 'name': 'extreme violence'}, {'id': 15363, 'name': 'bank robbery'}, {'id': 18072, 'name': 'preacher'}, {'id': 18233, 'name': 'hostage situation'}, {'id': 41380, 'name': 'crucifix'}, {'id': 163795, 'name': 'recreational vehicle'}, {'id': 167664, 'name': 'blood spurting'}, {'id': 168152, 'name': 'convenience store'}, {'id': 174878, 'name': 'female vampire'}, {'id': 188711, 'name': 'mexican american border'}, {'id': 191441, 'name': 'nightclub entertainer'}, {'id': 227811, 'name': 'boa constrictor'}]",
#  "[{'id': 258, 'name': 'bomb'}, {'id': 416, 'name': 'miami'}, {'id': 572, 'name': 'sex'}, {'id': 703, 'name': 'detective'}, {'id': 772, 'name': 'handcuffs'}, {'id': 818, 'name': 'based on novel'}, {'id': 1562, 'name': 'hostage'}, {'id': 1812, 'name': 'fbi'}, {'id': 1930, 'name': 'kidnapping'}, {'id': 2808, 'name': 'russian'}, {'id': 3278, 'name': 'kgb'}, {'id': 3713, 'name': 'chase'}, {'id': 4426, 'name': 'sadism'}, {'id': 4530, 'name': 'parking garage'}, {'id': 4735, 'name': 'pizza'}, {'id': 5430, 'name': 'police protection'}, {'id': 6259, 'name': 'psychopath'}, {'id': 9714, 'name': 'remake'}, {'id': 9844, 'name': 'car crash'}, {'id': 10410, 'name': 'conspiracy'}, {'id': 10562, 'name': 'on the run'}, {'id': 10718, 'name': 'fugitive'}, {'id': 10950, 'name': 'shootout'}, {'id': 12371, 'name': 'gunfight'}, {'id': 13125, 'name': 'sadist'}, {'id': 14967, 'name': 'foot chase'}, {'id': 15167, 'name': 'police detective'}, {'id': 15321, 'name': 'police station'}, {'id': 15483, 'name': 'car chase'}, {'id': 18320, 'name': 'held at gunpoint'}, {'id': 18525, 'name': 'fbi agent'}, {'id': 33456, 'name': 'double cross'}, {'id': 34117, 'name': 'cult film'}, {'id': 155555, 'name': 'computer hacker'}, {'id': 156650, 'name': 'machine gun'}, {'id': 156788, 'name': 'swat team'}, {'id': 156816, 'name': 'grenade launcher'}, {'id': 158247, 'name': 'underwater scene'}, {'id': 176802, 'name': 'rogue agent'}, {'id': 181145, 'name': 'woman lawyer'}, {'id': 188294, 'name': 'damsel in distress'}]",
#  "[{'id': 3616, 'name': 'college'}]",
#  "[{'id': 90, 'name': 'paris'}, {'id': 745, 'name': 'nun'}, {'id': 2792, 'name': 'boxer'}, {'id': 10909, 'name': 'lawyer'}, {'id': 11508, 'name': 'jewish'}]",
#  "[{'id': 2778, 'name': 'florist'}, {'id': 10235, 'name': 'family relationships'}]",
#  "[{'id': 6381, 'name': 'loss of daughter'}, {'id': 6440, 'name': 'hit-and-run driving '}, {'id': 9748, 'name': 'revenge'}, {'id': 9937, 'name': 'suspense'}, {'id': 10183, 'name': 'independent film'}, {'id': 10614, 'name': 'tragedy'}]",
#  "[{'id': 1417, 'name': 'jurors'}, {'id': 1936, 'name': 'blackmail'}, {'id': 3012, 'name': 'court case'}, {'id': 5153, 'name': 'son'}, {'id': 11038, 'name': 'trial'}, {'id': 33519, 'name': 'courtroom'}]",
#  "[{'id': 1357, 'name': 'fish'}, {'id': 10594, 'name': 'money'}, {'id': 33648, 'name': 'celebration'}, {'id': 40846, 'name': 'goldfish'}]",
#  "[{'id': 494, 'name': 'father son relationship'}, {'id': 801, 'name': 'bounty hunter'}, {'id': 1422, 'name': 'boat'}, {'id': 1587, 'name': 'way of life'}, {'id': 1909, 'name': 'coffin'}, {'id': 1977, 'name': 'denver'}, {'id': 2022, 'name': 'godmother'}, {'id': 2340, 'name': 'paranoia'}, {'id': 2708, 'name': 'hitman'}, {'id': 6054, 'name': 'friendship'}, {'id': 6259, 'name': 'psychopath'}, {'id': 9748, 'name': 'revenge'}, {'id': 9826, 'name': 'murder'}, {'id': 10183, 'name': 'independent film'}, {'id': 10391, 'name': 'mafia'}, {'id': 10738, 'name': 'diner'}, {'id': 11221, 'name': 'blood'}, {'id': 13142, 'name': 'gangster'}, {'id': 14819, 'name': 'violence'}, {'id': 33625, 'name': 'illegal prostitution'}, {'id': 34094, 'name': 'extramarital affair'}]",
#  "[{'id': 236, 'name': 'suicide'}, {'id': 240, 'name': 'underdog'}, {'id': 460, 'name': 'free love'}, {'id': 490, 'name': 'philosophy'}, {'id': 570, 'name': 'rape'}, {'id': 791, 'name': 'mentally disabled'}, {'id': 936, 'name': 'loss of mother'}, {'id': 1842, 'name': 'village life'}, {'id': 1956, 'name': 'world war ii'}, {'id': 2383, 'name': 'feminism'}, {'id': 3154, 'name': 'indian summer '}, {'id': 3371, 'name': 'family history'}, {'id': 4129, 'name': 'widow'}, {'id': 4402, 'name': 'peasant'}, {'id': 5331, 'name': 'village'}, {'id': 6009, 'name': 'mathematics'}, {'id': 6089, 'name': 'freedom'}, {'id': 6145, 'name': 'right and justice'}, {'id': 9457, 'name': 'single'}, {'id': 10180, 'name': 'homosexuality'}, {'id': 10707, 'name': 'mother daughter relationship'}, {'id': 11925, 'name': 'domestic violence'}, {'id': 13160, 'name': 'university'}, {'id': 187056, 'name': 'woman director'}]",
#  "[{'id': 6984, 'name': 'racial segregation'}, {'id': 10235, 'name': 'family relationships'}, {'id': 11004, 'name': 'rural setting'}, {'id': 12532, 'name': 'african american'}]",
#  '[]',
#  "[{'id': 4034, 'name': 'class society'}, {'id': 7579, 'name': 'rich woman - poor man'}, {'id': 14760, 'name': 'scientist'}, {'id': 182662, 'name': 'naturalist'}, {'id': 208526, 'name': 'insect'}]",
#  "[{'id': 2082, 'name': 'sailing trip'}, {'id': 2913, 'name': 'diary'}, {'id': 3180, 'name': 'sailing'}, {'id': 10349, 'name': 'survival'}, {'id': 10683, 'name': 'coming of age'}, {'id': 18068, 'name': 'teenage boy'}, {'id': 46962, 'name': 'discipline'}, {'id': 167836, 'name': 'squall'}, {'id': 167837, 'name': 'sail'}, {'id': 167843, 'name': 'ship captain'}, {'id': 167861, 'name': 'caribbean'}, {'id': 167863, 'name': 'male bonding'}, {'id': 167868, 'name': 'seasickness'}, {'id': 168683, 'name': 'storm at sea'}, {'id': 208992, 'name': '1960s'}]",
#  "[{'id': 5306, 'name': 'boss'}, {'id': 5572, 'name': 'fistfight'}, {'id': 10624, 'name': 'bully'}, {'id': 14762, 'name': 'orangutan'}, {'id': 158039, 'name': 'hotel manager'}]",
#  "[{'id': 169078, 'name': 'nitrous oxide'}, {'id': 169079, 'name': 'candid camera'}, {'id': 169085, 'name': 'double act'}, {'id': 169086, 'name': 'political satire'}, {'id': 169097, 'name': 'crooked politician'}, {'id': 187056, 'name': 'woman director'}]",
#  "[{'id': 441, 'name': 'assassination'}, {'id': 477, 'name': 'train station'}, {'id': 6078, 'name': 'politics'}, {'id': 12670, 'name': 'los angeles'}]",
#  '[]',
#  "[{'id': 964, 'name': 'servant'}, {'id': 1299, 'name': 'monster'}, {'id': 10124, 'name': 'laboratory'}, {'id': 156033, 'name': 'jekyll and hyde'}, {'id': 191009, 'name': 'housemaid'}, {'id': 207928, 'name': '19th century'}]",
#  "[{'id': 3133, 'name': 'vampire'}, {'id': 3630, 'name': 'half vampire'}]",
#  "[{'id': 155808, 'name': 'hometown'}]",
#  "[{'id': 720, 'name': 'helicopter'}, {'id': 1261, 'name': 'river'}, {'id': 1316, 'name': 'captain'}, {'id': 1353, 'name': 'underground'}, {'id': 1666, 'name': 'mexican standoff'}, {'id': 1825, 'name': 'countdown'}, {'id': 3203, 'name': 'pilot'}, {'id': 5572, 'name': 'fistfight'}, {'id': 8122, 'name': 'canyon'}, {'id': 9052, 'name': 'major'}, {'id': 10085, 'name': 'betrayal'}, {'id': 12371, 'name': 'gunfight'}, {'id': 13008, 'name': 'train'}, {'id': 14601, 'name': 'explosion'}, {'id': 15263, 'name': 'park ranger'}, {'id': 18034, 'name': 'desert'}, {'id': 162365, 'name': 'military'}, {'id': 208547, 'name': 'nuclear device'}, {'id': 209476, 'name': 'boxing'}, {'id': 214472, 'name': 'stealth aircraft'}, {'id': 215861, 'name': 'abandoned mine'}, {'id': 219869, 'name': 'humvee'}]",
#  "[{'id': 14531, 'name': 'play'}, {'id': 185011, 'name': 'hamlet'}, {'id': 207317, 'name': 'christmas'}, {'id': 207716, 'name': 'actor'}]",
#  "[{'id': 90, 'name': 'paris'}, {'id': 376, 'name': 'neo-nazi'}, {'id': 379, 'name': 'skinhead'}, {'id': 642, 'name': 'robbery'}, {'id': 796, 'name': 'police brutality'}, {'id': 898, 'name': 'hip-hop'}, {'id': 1419, 'name': 'gun'}, {'id': 1952, 'name': 'socially deprived family'}, {'id': 1974, 'name': 'breakdance'}, {'id': 1975, 'name': 'arabian'}, {'id': 3925, 'name': 'boredom'}, {'id': 9748, 'name': 'revenge'}, {'id': 14632, 'name': 'suburb'}, {'id': 14819, 'name': 'violence'}, {'id': 15090, 'name': 'police officer'}, {'id': 156052, 'name': 'unemployment'}, {'id': 156702, 'name': 'capture'}, {'id': 160910, 'name': 'xenophobia'}]",
#  '[]',
#  "[{'id': 2398, 'name': 'narration'}, {'id': 12396, 'name': 'hollywood'}, {'id': 13059, 'name': 'prostitution'}]",
#  "[{'id': 417, 'name': 'corruption'}, {'id': 1568, 'name': 'undercover'}, {'id': 1601, 'name': 'war on drugs'}, {'id': 1919, 'name': 'mayor'}, {'id': 2231, 'name': 'drug dealer'}, {'id': 2946, 'name': 'presidential election'}, {'id': 4654, 'name': 'undercover agent'}, {'id': 5340, 'name': 'investigation'}, {'id': 6149, 'name': 'police'}, {'id': 14964, 'name': 'drug'}]",
#  "[{'id': 380, 'name': 'brother brother relationship'}, {'id': 642, 'name': 'robbery'}, {'id': 1437, 'name': 'burglar'}, {'id': 2568, 'name': 'language barrier'}, {'id': 2669, 'name': 'motel'}, {'id': 10183, 'name': 'independent film'}, {'id': 10323, 'name': 'psychiatric hospital'}, {'id': 13097, 'name': 'maid'}, {'id': 14604, 'name': 'theft'}, {'id': 15274, 'name': 'nervous breakdown'}, {'id': 187710, 'name': 'escapade'}, {'id': 187717, 'name': 'laundry room'}]",
#  '[]',
#  "[{'id': 1157, 'name': 'wife husband relationship'}, {'id': 1706, 'name': 'experiment'}, {'id': 6149, 'name': 'police'}, {'id': 9826, 'name': 'murder'}, {'id': 9937, 'name': 'suspense'}, {'id': 10937, 'name': 'memory'}, {'id': 160313, 'name': 'forensic'}, {'id': 163114, 'name': 'gunman'}, {'id': 168069, 'name': 'animal experimentation'}]",
#  "[{'id': 936, 'name': 'loss of mother'}, {'id': 1872, 'name': 'loss of father'}, {'id': 2702, 'name': 'golf'}, {'id': 6075, 'name': 'sport'}, {'id': 6128, 'name': 'taxes'}]",
#  '[{\'id\': 455, \'name\': \'farewell\'}, {\'id\': 596, \'name\': \'adultery\'}, {\'id\': 699, \'name\': \'love at first sight\'}, {\'id\': 1003, \'name\': \'photographer\'}, {\'id\': 1157, \'name\': \'wife husband relationship\'}, {\'id\': 2029, \'name\': \'iowa\'}, {\'id\': 2038, \'name\': "love of one\'s life"}, {\'id\': 2784, \'name\': \'mother role\'}, {\'id\': 3450, \'name\': \'bridge\'}, {\'id\': 3451, \'name\': \'housewife\'}, {\'id\': 3452, \'name\': \'love letter\'}, {\'id\': 4402, \'name\': \'peasant\'}, {\'id\': 5809, \'name\': \'marriage crisis\'}, {\'id\': 6025, \'name\': \'photography\'}, {\'id\': 6059, \'name\': \'unsociability\'}, {\'id\': 7879, \'name\': \'secret love\'}, {\'id\': 221355, \'name\': \'nature documentary\'}]',
#  "[{'id': 530, 'name': 'prophecy'}, {'id': 3392, 'name': 'voodoo'}, {'id': 9457, 'name': 'single'}, {'id': 13072, 'name': 'falling in love'}, {'id': 187056, 'name': 'woman director'}, {'id': 196682, 'name': 'rich man'}]",
#  "[{'id': 2041, 'name': 'island'}, {'id': 4418, 'name': 'pirate gang'}, {'id': 6300, 'name': 'puppet'}, {'id': 6956, 'name': 'treasure hunt'}]",
#  '[]',
#  "[{'id': 156121, 'name': 'ex-con'}]",
#  "[{'id': 30, 'name': 'individual'}, {'id': 388, 'name': 'scotland'}, {'id': 930, 'name': 'in love with enemy'}, {'id': 3754, 'name': 'legend'}, {'id': 4097, 'name': 'independence'}, {'id': 6987, 'name': 'idealism'}, {'id': 162845, 'name': 'revolt'}, {'id': 189433, 'name': 'tyranny'}]",
#  "[{'id': 422, 'name': 'vietnam veteran'}, {'id': 444, 'name': 'taxi'}, {'id': 1523, 'name': 'obsession'}, {'id': 2231, 'name': 'drug dealer'}, {'id': 4225, 'name': 'night shift'}, {'id': 7002, 'name': 'vigilante'}, {'id': 7368, 'name': 'alienation'}, {'id': 9622, 'name': 'misanthrope'}, {'id': 11325, 'name': 'shot to death'}, {'id': 33625, 'name': 'illegal prostitution'}, {'id': 167104, 'name': 'loner'}]",
#  "[{'id': 242, 'name': 'new york'}, {'id': 779, 'name': 'martial arts'}, {'id': 1545, 'name': 'supermarket'}, {'id': 2987, 'name': 'gang war'}, {'id': 4640, 'name': 'disabled child'}, {'id': 10726, 'name': 'gang'}, {'id': 13027, 'name': 'wedding'}, {'id': 33461, 'name': 'diamond'}, {'id': 161307, 'name': 'bronx'}, {'id': 179431, 'name': 'duringcreditsstinger'}]",
#  '[]',
#  "[{'id': 6015, 'name': 'mining'}, {'id': 40897, 'name': 'dance lesson'}, {'id': 164742, 'name': 'coal mining'}, {'id': 188645, 'name': 'bagpipes'}]",
#  "[{'id': 12392, 'name': 'best friend'}, {'id': 15016, 'name': 'twins'}, {'id': 17953, 'name': 'country'}, {'id': 177035, 'name': 'identity swap'}, {'id': 187056, 'name': 'woman director'}]",
#  "[{'id': 1755, 'name': 'fascism'}, {'id': 2450, 'name': 'auschwitz'}, {'id': 4020, 'name': 'typhus'}, {'id': 4399, 'name': 'victim'}, {'id': 4434, 'name': 'interview'}, {'id': 10360, 'name': 'prejudice'}, {'id': 11728, 'name': 'burglary'}, {'id': 15199, 'name': 'rabbit'}]",
#  "[{'id': 212, 'name': 'london england'}, {'id': 351, 'name': 'poison'}, {'id': 9672, 'name': 'based on true story'}, {'id': 9826, 'name': 'murder'}, {'id': 10714, 'name': 'serial killer'}, {'id': 11857, 'name': 'mental institution'}, {'id': 13130, 'name': 'teenager'}, {'id': 15106, 'name': 'psychiatrist'}, {'id': 232550, 'name': 'stepmother'}, {'id': 234682, 'name': 'social misfit'}]",
#  "[{'id': 1253, 'name': 'roommate'}, {'id': 9457, 'name': 'single'}, {'id': 9673, 'name': 'love'}, {'id': 10183, 'name': 'independent film'}, {'id': 12392, 'name': 'best friend'}, {'id': 158967, 'name': 'brooklyn bridge'}]",
#  "[{'id': 380, 'name': 'brother brother relationship'}, {'id': 7375, 'name': 'twin brother'}, {'id': 10909, 'name': 'lawyer'}, {'id': 155881, 'name': 'estate'}, {'id': 208563, 'name': 'santa barbara california'}]",
#  "[{'id': 1668, 'name': 'hawaii'}, {'id': 5657, 'name': 'australia'}, {'id': 10508, 'name': 'teacher'}, {'id': 33885, 'name': 'car'}, {'id': 175976, 'name': 'solar power'}]",
#  '[]',
#  '[{\'id\': 2273, \'name\': \'role of women\'}, {\'id\': 2336, \'name\': \'ladykiller\'}, {\'id\': 3836, \'name\': \'success\'}, {\'id\': 6779, \'name\': "ladies\' man"}, {\'id\': 7769, \'name\': \'chefin\'}, {\'id\': 8642, \'name\': \'casanova\'}, {\'id\': 9094, \'name\': \'womanizer\'}]',
#  "[{'id': 1595, 'name': 'ex-girlfriend'}, {'id': 3391, 'name': 'drug smuggle'}, {'id': 5490, 'name': 'girlfriend'}, {'id': 6618, 'name': 'snack bar'}, {'id': 9840, 'name': 'romance'}, {'id': 12354, 'name': 'hong kong'}, {'id': 180294, 'name': 'pineapple'}, {'id': 185265, 'name': 'expiration date'}, {'id': 185266, 'name': 'flight attendant'}]",
#  '[]',
#  "[{'id': 5498, 'name': 'lsd'}, {'id': 6230, 'name': 'looking for  birth parents'}, {'id': 6231, 'name': 'half-brother'}, {'id': 10183, 'name': 'independent film'}]",
#  "[{'id': 334, 'name': 'flying'}, {'id': 2343, 'name': 'magic'}]",
#  "[{'id': 187056, 'name': 'woman director'}]",
#  '[]',
#  '[]',
#  "[{'id': 10183, 'name': 'independent film'}, {'id': 187056, 'name': 'woman director'}]",
#  "[{'id': 5202, 'name': 'boy'}, {'id': 13028, 'name': 'writer'}, {'id': 14985, 'name': 'ireland'}, {'id': 187844, 'name': 'flashback'}, {'id': 208501, 'name': 'troop ship'}]",
#  "[{'id': 550, 'name': 'callgirl'}, {'id': 582, 'name': 'san francisco'}, {'id': 5340, 'name': 'investigation'}, {'id': 9826, 'name': 'murder'}]",
#  "[{'id': 242, 'name': 'new york'}, {'id': 1625, 'name': 'emigration'}, {'id': 190019, 'name': 'dominican republic'}]",
#  '[]',
#  "[{'id': 339, 'name': 'submarine'}, {'id': 4410, 'name': 'u.s. navy'}, {'id': 9789, 'name': 'misfit'}]",
#  "[{'id': 5565, 'name': 'biography'}]",
#  "[{'id': 10180, 'name': 'homosexuality'}, {'id': 10183, 'name': 'independent film'}, {'id': 11800, 'name': 'mockumentary'}]",
#  "[{'id': 531, 'name': 'southern usa'}, {'id': 818, 'name': 'based on novel'}, {'id': 10229, 'name': 'singer'}, {'id': 207981, 'name': 'south'}]",
#  '[]',
#  "[{'id': 238179, 'name': 'skab under tv'}, {'id': 238241, 'name': 'foran'}, {'id': 238242, 'name': 'nederste hylde'}]",
#  "[{'id': 237, 'name': 'gay'}, {'id': 824, 'name': 'drag queen'}, {'id': 1013, 'name': 'homophobia'}, {'id': 1196, 'name': 'florida'}, {'id': 1862, 'name': 'coming out'}, {'id': 2944, 'name': 'senator'}, {'id': 6083, 'name': 'politician'}, {'id': 158718, 'name': 'lgbt'}, {'id': 201554, 'name': 'crossdressing'}, {'id': 210608, 'name': '1990s'}]",
#  "[{'id': 1262, 'name': 'mountain'}, {'id': 2618, 'name': 'miracle'}, {'id': 10164, 'name': 'apparition'}, {'id': 173644, 'name': 'communism'}, {'id': 178611, 'name': 'virgin mary'}]",
#  "[{'id': 9673, 'name': 'love'}, {'id': 10183, 'name': 'independent film'}, {'id': 12392, 'name': 'best friend'}, {'id': 188993, 'name': 'true love'}, {'id': 208725, 'name': 'irish catholic'}]",
#  "[{'id': 1653, 'name': 'explosive'}, {'id': 9748, 'name': 'revenge'}, {'id': 159358, 'name': 'explosives expert'}]",
#  '[]',
#  "[{'id': 416, 'name': 'miami'}, {'id': 703, 'name': 'detective'}, {'id': 772, 'name': 'handcuffs'}, {'id': 822, 'name': 'airport'}, {'id': 1666, 'name': 'mexican standoff'}, {'id': 3688, 'name': 'strip club'}, {'id': 4009, 'name': 'witness protection'}, {'id': 9844, 'name': 'car crash'}, {'id': 11730, 'name': 'internal affairs'}, {'id': 12371, 'name': 'gunfight'}, {'id': 14601, 'name': 'explosion'}, {'id': 14707, 'name': 'brutality'}, {'id': 14967, 'name': 'foot chase'}, {'id': 15483, 'name': 'car chase'}, {'id': 18026, 'name': 'drug lord'}, {'id': 166856, 'name': 'hangar'}, {'id': 167114, 'name': 'loose cannon'}, {'id': 167115, 'name': 'bust'}, {'id': 167119, 'name': 'reference to skittles'}, {'id': 167124, 'name': 'black cop'}, {'id': 167128, 'name': 'badge'}, {'id': 219404, 'name': 'action hero'}, {'id': 226376, 'name': 'corrupt cop'}]",
#  "[{'id': 478, 'name': 'china'}, {'id': 8531, 'name': 'panda'}, {'id': 8723, 'name': 'poacher'}]",
#  "[{'id': 6075, 'name': 'sport'}, {'id': 6496, 'name': 'basketball'}, {'id': 6782, 'name': 'addiction'}, {'id': 9713, 'name': 'friends'}, {'id': 14964, 'name': 'drug'}]",
#  "[{'id': 392, 'name': 'england'}, {'id': 818, 'name': 'based on novel'}, {'id': 6344, 'name': 'liverpool'}, {'id': 206032, 'name': 'theatre company'}, {'id': 207883, 'name': '1940s'}]",
#  "[{'id': 10183, 'name': 'independent film'}]",
#  "[{'id': 305, 'name': 'moon'}, {'id': 1196, 'name': 'florida'}, {'id': 1432, 'name': 'nasa'}, {'id': 2345, 'name': 'spaceman'}, {'id': 4776, 'name': 'race against time'}, {'id': 9609, 'name': 'houston'}, {'id': 9672, 'name': 'based on true story'}, {'id': 9882, 'name': 'space'}, {'id': 10084, 'name': 'rescue'}, {'id': 10349, 'name': 'survival'}, {'id': 10617, 'name': 'disaster'}, {'id': 14601, 'name': 'explosion'}, {'id': 14626, 'name': 'astronaut'}, {'id': 156395, 'name': 'imax'}, {'id': 184994, 'name': 'saturn v rocket'}, {'id': 189098, 'name': 'courage'}, {'id': 193479, 'name': 'hypothermia'}, {'id': 226233, 'name': 'apollo program'}, {'id': 226234, 'name': 'cape kennedy'}, {'id': 226235, 'name': 'lunar mission'}, {'id': 226236, 'name': 'spacecraft accident'}]",
#  "[{'id': 388, 'name': 'scotland'}, {'id': 5565, 'name': 'biography'}, {'id': 160279, 'name': '18th century'}, {'id': 208070, 'name': 'highlands'}, {'id': 220446, 'name': 'violent man'}]",
#  "[{'id': 242, 'name': 'new york'}, {'id': 490, 'name': 'philosophy'}, {'id': 3133, 'name': 'vampire'}, {'id': 11221, 'name': 'blood'}, {'id': 12105, 'name': 'student'}, {'id': 14819, 'name': 'violence'}]",
#  "[{'id': 483, 'name': 'riddle'}, {'id': 849, 'name': 'dc comics'}, {'id': 3259, 'name': 'rose'}, {'id': 6969, 'name': 'gotham city'}, {'id': 9104, 'name': 'partner'}, {'id': 9715, 'name': 'superhero'}, {'id': 10486, 'name': 'robin'}, {'id': 10525, 'name': 'broken neck'}, {'id': 11268, 'name': 'psychologist'}, {'id': 14819, 'name': 'violence'}, {'id': 15009, 'name': 'criminal'}, {'id': 33518, 'name': 'district attorney'}, {'id': 33626, 'name': 'millionaire'}, {'id': 33981, 'name': 'falling down stairs'}, {'id': 34156, 'name': 'tied up'}, {'id': 156116, 'name': 'tommy gun'}, {'id': 157166, 'name': 'beretta'}, {'id': 157583, 'name': 'knocked out'}, {'id': 163455, 'name': 'super powers'}, {'id': 170383, 'name': 'disfigurement'}, {'id': 170652, 'name': 'father figure'}]",
#  '[{\'id\': 549, \'name\': \'prostitute\'}, {\'id\': 596, \'name\': \'adultery\'}, {\'id\': 848, \'name\': \'double life\'}, {\'id\': 851, \'name\': \'dual identity\'}, {\'id\': 931, \'name\': \'jealousy\'}, {\'id\': 1157, \'name\': \'wife husband relationship\'}, {\'id\': 1411, \'name\': \'brothel\'}, {\'id\': 1566, \'name\': \'dream\'}, {\'id\': 2316, \'name\': "women\'s sexual identity"}, {\'id\': 2486, \'name\': \'fantasy\'}, {\'id\': 3260, \'name\': \'masochism\'}, {\'id\': 10183, \'name\': \'independent film\'}]',
#  "[{'id': 5499, 'name': 'burma'}, {'id': 5855, 'name': 'rangoon'}, {'id': 13005, 'name': 'doctor'}]",
#  "[{'id': 919, 'name': 'smoking'}, {'id': 1901, 'name': 'corner shop'}, {'id': 3170, 'name': 'cigarette'}, {'id': 6357, 'name': 'tobacco'}, {'id': 6458, 'name': 'cigar'}, {'id': 10183, 'name': 'independent film'}]",
#  '[]',
#  "[{'id': 3335, 'name': 'halloween'}, {'id': 6054, 'name': 'friendship'}, {'id': 6152, 'name': 'supernatural'}, {'id': 6155, 'name': 'afterlife'}, {'id': 9713, 'name': 'friends'}, {'id': 15017, 'name': 'danger'}, {'id': 162846, 'name': 'ghost'}, {'id': 189449, 'name': 'disorder'}, {'id': 193545, 'name': 'young heroes'}, {'id': 202322, 'name': 'imaginary'}, {'id': 206813, 'name': 'supernatural ability'}, {'id': 206834, 'name': 'mischievous children'}]",
#  "[{'id': 11505, 'name': 'drug pusher'}, {'id': 13008, 'name': 'train'}, {'id': 14964, 'name': 'drug'}, {'id': 18026, 'name': 'drug lord'}]",
#  "[{'id': 690, 'name': 'gorilla'}, {'id': 2521, 'name': 'kongo'}, {'id': 3379, 'name': 'diamond mine'}, {'id': 33461, 'name': 'diamond'}]",
#  "[{'id': 339, 'name': 'submarine'}, {'id': 1860, 'name': 'mutiny'}, {'id': 2139, 'name': 'russia'}, {'id': 2534, 'name': 'missile'}, {'id': 3312, 'name': 'nuclear missile'}, {'id': 4123, 'name': 'embassy'}, {'id': 4410, 'name': 'u.s. navy'}, {'id': 4933, 'name': 'battle for power'}, {'id': 6791, 'name': 'torpedo'}, {'id': 162365, 'name': 'military'}, {'id': 198423, 'name': 'moral dilemma'}, {'id': 217133, 'name': 'post cold war'}, {'id': 221092, 'name': 'aircraft carrier'}, {'id': 226740, 'name': 'chain of command'}, {'id': 226741, 'name': 'launch code'}, {'id': 226742, 'name': 'sonar'}]",
#  "[{'id': 1353, 'name': 'underground'}, {'id': 5565, 'name': 'biography'}, {'id': 14893, 'name': 'art'}]",
#  "[{'id': 75, 'name': 'gunslinger'}, {'id': 139, 'name': 'anti terror'}, {'id': 502, 'name': 'ambush'}, {'id': 534, 'name': 'mexico'}, {'id': 797, 'name': 'showdown'}, {'id': 953, 'name': 'guitar'}, {'id': 2483, 'name': 'nudity'}, {'id': 2708, 'name': 'hitman'}, {'id': 3458, 'name': 'bartender'}, {'id': 9748, 'name': 'revenge'}, {'id': 10044, 'name': 'tragic hero'}, {'id': 10950, 'name': 'shootout'}, {'id': 14575, 'name': 'mariachi'}, {'id': 14601, 'name': 'explosion'}, {'id': 14687, 'name': 'extreme violence'}, {'id': 14707, 'name': 'brutality'}, {'id': 18026, 'name': 'drug lord'}, {'id': 41372, 'name': 'leg brace'}, {'id': 154889, 'name': 'concealed weapon'}, {'id': 187844, 'name': 'flashback'}, {'id': 226790, 'name': 'bookstore'}]",
#  "[{'id': 5823, 'name': 'jazz club'}, {'id': 9826, 'name': 'murder'}, {'id': 12670, 'name': 'los angeles'}, {'id': 155790, 'name': 'private detective'}, {'id': 195402, 'name': 'film noir'}, {'id': 207268, 'name': 'neo-noir'}]",
#  "[{'id': 919, 'name': 'smoking'}, {'id': 1621, 'name': 'robber'}, {'id': 3170, 'name': 'cigarette'}, {'id': 6458, 'name': 'cigar'}, {'id': 8736, 'name': 'laden'}, {'id': 10183, 'name': 'independent film'}, {'id': 13028, 'name': 'writer'}]",
#  "[{'id': 2673, 'name': 'horse'}, {'id': 7323, 'name': 'savannah'}, {'id': 9672, 'name': 'based on true story'}, {'id': 18035, 'name': 'family'}]",
#  "[{'id': 4750, 'name': 'red-light disctrict'}, {'id': 164682, 'name': 'stuart sutcliffe'}, {'id': 164698, 'name': 'boyfriend girlfriend'}, {'id': 164700, 'name': 'river elbe'}, {'id': 164704, 'name': 'hofner bass guitar'}, {'id': 164705, 'name': 'body painting'}, {'id': 164713, 'name': 'hamburg germany'}, {'id': 164715, 'name': 'photo'}, {'id': 164716, 'name': 'reeperbahn'}]",
#  "[{'id': 258, 'name': 'bomb'}, {'id': 444, 'name': 'taxi'}, {'id': 483, 'name': 'riddle'}, {'id': 642, 'name': 'robbery'}, {'id': 703, 'name': 'detective'}, {'id': 720, 'name': 'helicopter'}, {'id': 1321, 'name': 'gold'}, {'id': 1552, 'name': 'subway'}, {'id': 3799, 'name': 'ship'}, {'id': 5572, 'name': 'fistfight'}, {'id': 6149, 'name': 'police'}, {'id': 9663, 'name': 'sequel'}, {'id': 9758, 'name': 'deception'}, {'id': 10950, 'name': 'shootout'}, {'id': 14512, 'name': 'new york city'}, {'id': 14601, 'name': 'explosion'}, {'id': 14819, 'name': 'violence'}, {'id': 15483, 'name': 'car chase'}, {'id': 18525, 'name': 'fbi agent'}, {'id': 177309, 'name': 'simon says'}, {'id': 187844, 'name': 'flashback'}, {'id': 188329, 'name': 'dump truck'}, {'id': 192707, 'name': 'aqueduct'}, {'id': 219404, 'name': 'action hero'}, {'id': 226838, 'name': 'federal reserve bank'}]",
#  "[{'id': 572, 'name': 'sex'}, {'id': 1664, 'name': 'eroticism'}, {'id': 2483, 'name': 'nudity'}, {'id': 2652, 'name': 'nazis'}, {'id': 9937, 'name': 'suspense'}, {'id': 13017, 'name': 'drifter'}, {'id': 180340, 'name': 'voyeur'}]",
#  '[]',
#  "[{'id': 3966, 'name': 'camelot'}, {'id': 10466, 'name': 'knight'}, {'id': 10982, 'name': 'king arthur'}, {'id': 177128, 'name': 'excalibur'}, {'id': 177129, 'name': 'knights of the round table'}]",
#  "[{'id': 2526, 'name': 'human animal relationship'}, {'id': 4676, 'name': 'whale'}, {'id': 155529, 'name': 'killer whale'}]",
#  "[{'id': 293, 'name': 'female nudity'}, {'id': 2157, 'name': 'hacker'}, {'id': 2483, 'name': 'nudity'}, {'id': 2812, 'name': 'computer virus'}, {'id': 4563, 'name': 'virtual reality'}, {'id': 6104, 'name': 'computer'}, {'id': 9835, 'name': 'sexual fantasy'}, {'id': 9864, 'name': 'prank'}, {'id': 11615, 'name': 'internet'}, {'id': 12190, 'name': 'cyberpunk'}, {'id': 13130, 'name': 'teenager'}, {'id': 14512, 'name': 'new york city'}, {'id': 41249, 'name': 'secret service'}, {'id': 155555, 'name': 'computer hacker'}, {'id': 160840, 'name': 'dream sequence'}]",
#  "[{'id': 237, 'name': 'gay'}, {'id': 740, 'name': 'aids'}, {'id': 10181, 'name': 'based on play or musical'}, {'id': 165770, 'name': 'hiv positive'}]",
#  "[{'id': 2588, 'name': 'brain'}, {'id': 3321, 'name': 'childhood memory'}, {'id': 4565, 'name': 'dystopia'}, {'id': 6135, 'name': 'pharmaceutical industry'}, {'id': 6566, 'name': 'computer chip'}, {'id': 8662, 'name': 'courier'}, {'id': 10919, 'name': 'cyber'}, {'id': 12190, 'name': 'cyberpunk'}]",
#  "[{'id': 934, 'name': 'judge'}, {'id': 4458, 'name': 'post-apocalyptic'}, {'id': 4565, 'name': 'dystopia'}, {'id': 9717, 'name': 'based on comic'}, {'id': 15090, 'name': 'police officer'}, {'id': 18712, 'name': 'based on graphic novel'}, {'id': 160159, 'name': 'frame up'}, {'id': 162988, 'name': 'dystopic future'}, {'id': 180172, 'name': 'framed for murder'}, {'id': 182703, 'name': 'gene'}, {'id': 182706, 'name': 'prosthetic limb'}, {'id': 182709, 'name': 'post holocaust'}, {'id': 182711, 'name': 'dna testing'}, {'id': 203165, 'name': 'dredd'}, {'id': 236590, 'name': '2000 ad'}]",
#  "[{'id': 6593, 'name': 'stripper'}, {'id': 8881, 'name': 'jury'}, {'id': 9465, 'name': 'jurist'}, {'id': 10183, 'name': 'independent film'}, {'id': 10639, 'name': 'jury duty'}, {'id': 10640, 'name': 'verdict'}]",
#  "[{'id': 1525, 'name': 'puberty'}, {'id': 2201, 'name': 'first time'}]",
#  "[{'id': 1388, 'name': 'cinema'}, {'id': 10183, 'name': 'independent film'}, {'id': 11614, 'name': 'filmmaker'}]",
#  "[{'id': 3419, 'name': 'fanatic'}, {'id': 6152, 'name': 'supernatural'}, {'id': 6333, 'name': 'wizardry'}, {'id': 6506, 'name': 'resurrection'}, {'id': 173162, 'name': 'sect'}, {'id': 221387, 'name': 'occultism'}]",
#  '[]',
#  "[{'id': 1252, 'name': 'suicide attempt'}, {'id': 3616, 'name': 'college'}, {'id': 10049, 'name': 'teen angst'}, {'id': 41329, 'name': 'mental illness'}, {'id': 187056, 'name': 'woman director'}]",
#  "[{'id': 572, 'name': 'sex'}, {'id': 4325, 'name': 'game show'}, {'id': 8631, 'name': 'slacker'}, {'id': 41175, 'name': 'shopping'}, {'id': 157690, 'name': 'mall'}, {'id': 162296, 'name': 'ex-boyfriend ex-girlfriend relationship'}, {'id': 168033, 'name': 'jay and silent bob'}, {'id': 171329, 'name': 'silent man'}, {'id': 171343, 'name': 'coke'}, {'id': 171346, 'name': 'bandleader'}, {'id': 179430, 'name': 'aftercreditsstinger'}]",
#  "[{'id': 10988, 'name': 'based on tv series'}, {'id': 12667, 'name': 'tokusatsu'}, {'id': 155030, 'name': 'superhero team'}, {'id': 173577, 'name': 'ethnic diversity'}, {'id': 191474, 'name': 'super sentai'}, {'id': 201635, 'name': 'power rangers'}, {'id': 203223, 'name': 'mighty morphin power rangers'}, {'id': 203224, 'name': 'mmpr'}]",
#  "[{'id': 4129, 'name': 'widow'}, {'id': 5248, 'name': 'female friendship'}, {'id': 9872, 'name': 'grief'}, {'id': 175421, 'name': 'death of husband'}]",
#  "[{'id': 3713, 'name': 'chase'}, {'id': 6149, 'name': 'police'}, {'id': 9826, 'name': 'murder'}, {'id': 10392, 'name': 'mute'}, {'id': 197452, 'name': 'disk'}]",
#  "[{'id': 242, 'name': 'new york'}, {'id': 3133, 'name': 'vampire'}, {'id': 3633, 'name': 'dracula'}]",
# ...
#  "[{'id': 30, 'name': 'individual'}, {'id': 380, 'name': 'brother brother relationship'}, {'id': 526, 'name': 'rebel'}, {'id': 531, 'name': 'southern usa'}, {'id': 1421, 'name': 'birthday'}, {'id': 3534, 'name': 'big wheel'}, {'id': 9673, 'name': 'love'}, {'id': 10594, 'name': 'money'}, {'id': 46958, 'name': 'good and bad'}, {'id': 189599, 'name': 'beans'}]",
#  "[{'id': 703, 'name': 'detective'}, {'id': 1436, 'name': 'inventor'}, {'id': 6149, 'name': 'police'}, {'id': 9826, 'name': 'murder'}, {'id': 11869, 'name': 'mistress'}, {'id': 12997, 'name': 'dinner'}, {'id': 13027, 'name': 'wedding'}, {'id': 155457, 'name': 'screwball comedy'}, {'id': 158225, 'name': 'terrier'}, {'id': 173685, 'name': 'thin man'}, {'id': 197362, 'name': 'x-ray'}]",
#  "[{'id': 236, 'name': 'suicide'}, {'id': 378, 'name': 'prison'}, {'id': 736, 'name': 'journalist'}, {'id': 917, 'name': 'journalism'}, {'id': 10718, 'name': 'fugitive'}, {'id': 11411, 'name': 'wager'}, {'id': 156080, 'name': 'newspaper editor'}, {'id': 159531, 'name': 'insurance agent'}, {'id': 165547, 'name': 'fiancé fiancée relationship'}, {'id': 169097, 'name': 'crooked politician'}, {'id': 180093, 'name': 'press room'}, {'id': 181659, 'name': 'political corruption'}, {'id': 184534, 'name': 'rolltop desk'}, {'id': 184541, 'name': 'reprieve'}, {'id': 209563, 'name': 'bride-to-be'}, {'id': 236252, 'name': 'ex spouses'}, {'id': 237418, 'name': 'imminent execution'}, {'id': 237425, 'name': 'convicted murderer'}]",
#  "[{'id': 279, 'name': 'usa'}, {'id': 385, 'name': 'jules verne'}, {'id': 622, 'name': 'bet'}, {'id': 703, 'name': 'detective'}, {'id': 1293, 'name': 'asia'}, {'id': 1295, 'name': 'europe'}, {'id': 1582, 'name': 'saloon'}, {'id': 3497, 'name': 'hot air balloon'}, {'id': 6917, 'name': 'epic'}, {'id': 13008, 'name': 'train'}, {'id': 33493, 'name': 'valet'}, {'id': 168277, 'name': 'around the world'}, {'id': 189092, 'name': 'journey'}, {'id': 191101, 'name': 'steamship'}]",
#  "[{'id': 65, 'name': 'holiday'}, {'id': 290, 'name': 'angel'}, {'id': 818, 'name': 'based on novel'}, {'id': 974, 'name': 'bank'}, {'id': 1252, 'name': 'suicide attempt'}, {'id': 1415, 'name': 'small town'}, {'id': 5570, 'name': 'christmas tree'}, {'id': 5571, 'name': 'great depression'}, {'id': 33965, 'name': 'christmas eve'}, {'id': 156115, 'name': 'feel-good ending'}, {'id': 184559, 'name': 'guardian angel'}, {'id': 207317, 'name': 'christmas'}]",
#  "[{'id': 417, 'name': 'corruption'}, {'id': 521, 'name': 'washington d.c.'}, {'id': 1399, 'name': 'senate'}, {'id': 2944, 'name': 'senator'}, {'id': 5744, 'name': 'governor'}, {'id': 6083, 'name': 'politician'}, {'id': 11663, 'name': 'camp'}, {'id': 11937, 'name': 'conservative'}, {'id': 206515, 'name': 'usa politics'}, {'id': 219903, 'name': 'political drama'}]",
#  "[{'id': 378, 'name': 'prison'}, {'id': 1651, 'name': 'donation'}, {'id': 2172, 'name': 'zoo'}, {'id': 2598, 'name': 'museum'}, {'id': 4477, 'name': 'paleontologist'}, {'id': 4478, 'name': 'leopard'}, {'id': 4479, 'name': 'bone'}, {'id': 155457, 'name': 'screwball comedy'}]",
#  "[{'id': 2676, 'name': 'honeymoon'}, {'id': 5097, 'name': 'sterility'}, {'id': 5600, 'name': 'daughter'}, {'id': 6118, 'name': 'finances'}, {'id': 10721, 'name': 'pregnant'}, {'id': 11093, 'name': 'parenthood'}, {'id': 156825, 'name': 'music store'}, {'id': 169866, 'name': 'reflection'}, {'id': 180831, 'name': 'newspaper publisher'}, {'id': 188028, 'name': 'extravagance'}]",
#  "[{'id': 154802, 'name': 'silent film'}]",
#  "[{'id': 163070, 'name': 'burlesque'}]",
#  "[{'id': 828, 'name': 'waitress'}, {'id': 1009, 'name': 'baby'}, {'id': 1824, 'name': 'self-destruction'}, {'id': 10048, 'name': 'unrequited love'}, {'id': 10911, 'name': 'inheritance'}, {'id': 13005, 'name': 'doctor'}, {'id': 14796, 'name': 'destruction'}, {'id': 159845, 'name': 'tuberculosis'}, {'id': 187677, 'name': 'medical school'}, {'id': 209090, 'name': 'unwed mother'}, {'id': 211082, 'name': 'mistreatment'}, {'id': 225686, 'name': 'aspiring artist'}, {'id': 237446, 'name': 'jilted woman'}, {'id': 238052, 'name': 'spurned man'}, {'id': 238053, 'name': 'club foot'}, {'id': 238054, 'name': 'destitution'}, {'id': 238055, 'name': 'vitriol'}]",
#  "[{'id': 290, 'name': 'angel'}, {'id': 934, 'name': 'judge'}, {'id': 6154, 'name': 'hell'}, {'id': 9673, 'name': 'love'}, {'id': 13142, 'name': 'gangster'}, {'id': 14999, 'name': 'devil'}]",
#  "[{'id': 392, 'name': 'england'}, {'id': 1158, 'name': 'grandfather grandson relationship'}, {'id': 7950, 'name': 'grocer'}, {'id': 10388, 'name': 'lord'}, {'id': 41523, 'name': 'brooklyn new york city'}, {'id': 161506, 'name': 'heir'}, {'id': 186894, 'name': 'scam artist'}, {'id': 193460, 'name': 'mother child separation'}, {'id': 194231, 'name': 'earl'}, {'id': 194260, 'name': 'shoeshine boy'}, {'id': 208570, 'name': 'aristocracy'}]",
#  "[{'id': 703, 'name': 'detective'}, {'id': 1859, 'name': 'arizona'}, {'id': 2752, 'name': 'ranch'}, {'id': 2792, 'name': 'boxer'}, {'id': 4487, 'name': 'boxing match'}, {'id': 6075, 'name': 'sport'}, {'id': 6149, 'name': 'police'}, {'id': 12193, 'name': 'reporter'}, {'id': 14845, 'name': 'dead end kids'}]",
#  "[{'id': 417, 'name': 'corruption'}, {'id': 1919, 'name': 'mayor'}, {'id': 10685, 'name': 'escape'}, {'id': 13147, 'name': 'snake oil'}, {'id': 13148, 'name': 'medicine show'}]",
#  "[{'id': 188901, 'name': 'quaker'}, {'id': 188907, 'name': 'street shootout'}, {'id': 188922, 'name': 'cattle rustling'}, {'id': 188924, 'name': 'outlaw gang'}, {'id': 188925, 'name': 'brunette'}, {'id': 188932, 'name': 'long black hair'}, {'id': 188933, 'name': 'bar fight'}, {'id': 188934, 'name': 'bar brawl'}, {'id': 188938, 'name': 'telegraph office'}, {'id': 188944, 'name': 'revolver'}, {'id': 188947, 'name': 'sidekick'}]",
#  "[{'id': 212, 'name': 'london england'}, {'id': 388, 'name': 'scotland'}, {'id': 770, 'name': 'scotland yard'}, {'id': 772, 'name': 'handcuffs'}, {'id': 1328, 'name': 'secret'}, {'id': 1491, 'name': 'entertainer'}, {'id': 2051, 'name': 'intelligence'}, {'id': 2311, 'name': 'cabaret'}, {'id': 4289, 'name': 'secret agent'}, {'id': 9826, 'name': 'murder'}, {'id': 10718, 'name': 'fugitive'}, {'id': 13008, 'name': 'train'}, {'id': 218567, 'name': 'memorization'}, {'id': 226499, 'name': 'manhunt'}, {'id': 236566, 'name': 'handcuffed together'}, {'id': 236567, 'name': 'held against will'}, {'id': 236568, 'name': 'bickering couple'}, {'id': 236569, 'name': 'wrongly accused'}]",
#  "[{'id': 131, 'name': 'italy'}, {'id': 1956, 'name': 'world war ii'}, {'id': 185454, 'name': 'u.s. military'}]",
#  "[{'id': 798, 'name': 'sheriff'}, {'id': 5672, 'name': 'billy the kid'}, {'id': 9550, 'name': 'doc holliday'}]",
#  '[]',
#  "[{'id': 409, 'name': 'africa'}, {'id': 440, 'name': 'missionary'}, {'id': 1261, 'name': 'river'}, {'id': 1333, 'name': 'desperation'}, {'id': 1422, 'name': 'boat'}, {'id': 1627, 'name': 'patriotism'}, {'id': 2504, 'name': 'world war i'}, {'id': 2509, 'name': 'hippopotamus'}, {'id': 2510, 'name': 'giraffe'}, {'id': 2511, 'name': 'methodist church'}, {'id': 2514, 'name': 'moqukito'}, {'id': 2516, 'name': 'boat wedding'}, {'id': 2517, 'name': 'leech'}, {'id': 2518, 'name': 'gin'}, {'id': 2519, 'name': 'canadian'}, {'id': 2520, 'name': 'tanzania'}, {'id': 2521, 'name': 'kongo'}, {'id': 3711, 'name': 'animal species'}, {'id': 3929, 'name': 'hope'}, {'id': 6150, 'name': 'faith'}]",
#  "[{'id': 131, 'name': 'italy'}, {'id': 966, 'name': 'beach'}, {'id': 1157, 'name': 'wife husband relationship'}, {'id': 2251, 'name': 'lie'}, {'id': 2398, 'name': 'narration'}, {'id': 9468, 'name': 'liar'}, {'id': 9727, 'name': 'thief'}, {'id': 10123, 'name': 'dark comedy'}, {'id': 15203, 'name': 'dry humour'}, {'id': 33611, 'name': 'exercise'}, {'id': 191026, 'name': 'port'}, {'id': 193154, 'name': 'uranium'}]",
#  "[{'id': 30, 'name': 'individual'}, {'id': 236, 'name': 'suicide'}, {'id': 531, 'name': 'southern usa'}, {'id': 596, 'name': 'adultery'}, {'id': 787, 'name': 'mississippi'}, {'id': 894, 'name': 'depression'}, {'id': 931, 'name': 'jealousy'}, {'id': 1157, 'name': 'wife husband relationship'}, {'id': 3737, 'name': 'dying and death'}, {'id': 33457, 'name': 'alcoholic'}]",
#  "[{'id': 90, 'name': 'paris'}, {'id': 8508, 'name': 'party'}, {'id': 9673, 'name': 'love'}, {'id': 13028, 'name': 'writer'}]",
#  "[{'id': 159201, 'name': 'baseball player'}, {'id': 160025, 'name': 'radio broadcast'}, {'id': 160035, 'name': 'suicide note'}, {'id': 160037, 'name': 'domain'}]",
#  "[{'id': 931, 'name': 'jealousy'}, {'id': 9727, 'name': 'thief'}, {'id': 187203, 'name': 'casbah'}]",
#  "[{'id': 4344, 'name': 'musical'}, {'id': 171346, 'name': 'bandleader'}]",
#  "[{'id': 131, 'name': 'italy'}, {'id': 428, 'name': 'nurse'}, {'id': 3452, 'name': 'love letter'}, {'id': 3776, 'name': 'officer'}, {'id': 10093, 'name': 'priest'}, {'id': 10685, 'name': 'escape'}, {'id': 11612, 'name': 'hospital'}, {'id': 12392, 'name': 'best friend'}, {'id': 156764, 'name': 'pre-code'}, {'id': 158547, 'name': 'air raid'}, {'id': 185034, 'name': 'ambulance driver'}, {'id': 185037, 'name': 'battle of the isonzo'}, {'id': 233360, 'name': 'air attack'}]",
#  "[{'id': 703, 'name': 'detective'}, {'id': 156105, 'name': 'hollywood bowl'}]",
#  '[]',
#  '[]',
#  "[{'id': 10183, 'name': 'independent film'}]",
#  "[{'id': 1415, 'name': 'small town'}, {'id': 2406, 'name': 'picnic'}, {'id': 15057, 'name': 'labor day'}]",
#  "[{'id': 237, 'name': 'gay'}, {'id': 10183, 'name': 'independent film'}]",
#  "[{'id': 4552, 'name': 'beer'}, {'id': 9673, 'name': 'love'}, {'id': 15111, 'name': 'drinking'}]",
#  '[]',
#  "[{'id': 936, 'name': 'loss of mother'}, {'id': 1329, 'name': 'canada'}, {'id': 1436, 'name': 'inventor'}, {'id': 5600, 'name': 'daughter'}, {'id': 10084, 'name': 'rescue'}, {'id': 10168, 'name': 'aviation'}, {'id': 10614, 'name': 'tragedy'}, {'id': 15169, 'name': 'goose'}, {'id': 15171, 'name': 'earring'}, {'id': 15172, 'name': 'shampoo'}, {'id': 15173, 'name': 'hang glider'}, {'id': 15174, 'name': 'ecology'}]",
#  "[{'id': 246, 'name': 'dancing'}, {'id': 894, 'name': 'depression'}, {'id': 910, 'name': 'bondage'}, {'id': 1879, 'name': 'shower'}, {'id': 2483, 'name': 'nudity'}, {'id': 2675, 'name': 'frigidity'}, {'id': 2800, 'name': 'psychology'}, {'id': 3582, 'name': 'bride'}, {'id': 5707, 'name': 'childhood trauma'}, {'id': 6038, 'name': 'marriage'}, {'id': 8508, 'name': 'party'}, {'id': 10085, 'name': 'betrayal'}, {'id': 11612, 'name': 'hospital'}, {'id': 13005, 'name': 'doctor'}, {'id': 13027, 'name': 'wedding'}, {'id': 40952, 'name': 'therapy'}, {'id': 169276, 'name': 'commitment'}, {'id': 178379, 'name': 'steam room'}, {'id': 208781, 'name': 'intimacy'}, {'id': 212642, 'name': 'abusive father'}, {'id': 222797, 'name': 'repression'}, {'id': 226457, 'name': 'adoration'}, {'id': 226458, 'name': 'sex therapist'}, {'id': 226459, 'name': 'spooning'}]",
#  "[{'id': 10229, 'name': 'singer'}, {'id': 33475, 'name': 'songwriter'}, {'id': 187056, 'name': 'woman director'}]",
#  "[{'id': 236, 'name': 'suicide'}, {'id': 380, 'name': 'brother brother relationship'}, {'id': 572, 'name': 'sex'}, {'id': 725, 'name': 'lovesickness'}, {'id': 931, 'name': 'jealousy'}, {'id': 1201, 'name': 'austria'}, {'id': 1605, 'name': 'new love'}, {'id': 1842, 'name': 'village life'}, {'id': 2802, 'name': 'mountain village'}, {'id': 3725, 'name': 'pregnancy and birth'}, {'id': 3737, 'name': 'dying and death'}, {'id': 4570, 'name': 'vorarlberg'}, {'id': 4572, 'name': 'organ'}, {'id': 4573, 'name': 'down syndrome'}, {'id': 5331, 'name': 'village'}, {'id': 6027, 'name': 'music'}, {'id': 6257, 'name': 'genius'}, {'id': 10794, 'name': 'snow'}, {'id': 11004, 'name': 'rural setting'}, {'id': 14527, 'name': 'storm'}, {'id': 14765, 'name': 'church'}, {'id': 160175, 'name': 'alps'}, {'id': 161207, 'name': 'catholicism'}]",
#  "[{'id': 2281, 'name': 'mistake in person'}, {'id': 3737, 'name': 'dying and death'}, {'id': 7375, 'name': 'twin brother'}, {'id': 8045, 'name': 'russian mafia'}]",
#  "[{'id': 393, 'name': 'civil war'}, {'id': 1721, 'name': 'fight'}, {'id': 2946, 'name': 'presidential election'}, {'id': 3538, 'name': 'freedom fighter'}, {'id': 4355, 'name': 'chinese civil war'}, {'id': 14985, 'name': 'ireland'}]",
#  "[{'id': 2486, 'name': 'fantasy'}, {'id': 4902, 'name': 'surprise'}, {'id': 6038, 'name': 'marriage'}, {'id': 9826, 'name': 'murder'}, {'id': 9937, 'name': 'suspense'}, {'id': 34143, 'name': 'rich'}, {'id': 156104, 'name': 'stranger'}, {'id': 187056, 'name': 'woman director'}]",
#  '[{\'id\': 1508, \'name\': \'new mexico\'}, {\'id\': 1815, \'name\': \'atomic bomb\'}, {\'id\': 1956, \'name\': \'world war ii\'}, {\'id\': 2038, \'name\': "love of one\'s life"}, {\'id\': 2411, \'name\': \'new orleans\'}, {\'id\': 4593, \'name\': \'atomic bomb test\'}, {\'id\': 13027, \'name\': \'wedding\'}, {\'id\': 159845, \'name\': \'tuberculosis\'}]',
#  "[{'id': 1416, 'name': 'jazz'}, {'id': 1946, 'name': 'restaurant'}, {'id': 10183, 'name': 'independent film'}, {'id': 10637, 'name': 'food'}, {'id': 14836, 'name': 'italian restaurant'}, {'id': 34068, 'name': 'feast'}]",
#  "[{'id': 947, 'name': 'prohibition'}, {'id': 1556, 'name': 'texas'}, {'id': 2987, 'name': 'gang war'}, {'id': 9193, 'name': 'whiskey'}, {'id': 10391, 'name': 'mafia'}, {'id': 10562, 'name': 'on the run'}, {'id': 156116, 'name': 'tommy gun'}, {'id': 188296, 'name': 'hired gun'}]",
#  "[{'id': 5562, 'name': 'fish market'}, {'id': 13017, 'name': 'drifter'}, {'id': 207268, 'name': 'neo-noir'}]",
#  "[{'id': 641, 'name': 'single parent'}, {'id': 2492, 'name': 'bank robber'}, {'id': 4813, 'name': 'last chance'}, {'id': 12670, 'name': 'los angeles'}]",
#  "[{'id': 9253, 'name': 'slapstick'}, {'id': 159753, 'name': 'ensemble cast'}, {'id': 159953, 'name': 'automobile racing'}, {'id': 196401, 'name': 'cross country race'}, {'id': 205850, 'name': 'turn of the century'}]",
#  "[{'id': 703, 'name': 'detective'}, {'id': 782, 'name': 'assassin'}, {'id': 931, 'name': 'jealousy'}, {'id': 1562, 'name': 'hostage'}, {'id': 2150, 'name': 'cocaine'}, {'id': 2483, 'name': 'nudity'}, {'id': 2708, 'name': 'hitman'}, {'id': 9826, 'name': 'murder'}, {'id': 11258, 'name': 'suicidal'}, {'id': 11454, 'name': 'scam'}, {'id': 12670, 'name': 'los angeles'}, {'id': 14601, 'name': 'explosion'}, {'id': 41379, 'name': 'argument'}, {'id': 192655, 'name': 'guns'}]",
#  "[{'id': 416, 'name': 'miami'}, {'id': 1490, 'name': 'cleaning lady'}, {'id': 7397, 'name': 'bakery'}, {'id': 9826, 'name': 'murder'}, {'id': 9937, 'name': 'suspense'}, {'id': 10714, 'name': 'serial killer'}, {'id': 11181, 'name': 'decapitation'}, {'id': 11221, 'name': 'blood'}, {'id': 14652, 'name': 'falling from height'}, {'id': 18098, 'name': 'samurai sword'}]",
#  '[]',
#  '[]',
#  "[{'id': 242, 'name': 'new york'}, {'id': 3262, 'name': 'surgeon'}, {'id': 6731, 'name': 'british'}, {'id': 9937, 'name': 'suspense'}, {'id': 10326, 'name': 'morgue'}, {'id': 11612, 'name': 'hospital'}, {'id': 13004, 'name': 'medical'}, {'id': 13005, 'name': 'doctor'}, {'id': 158025, 'name': 'medical research'}, {'id': 177127, 'name': 'emergency room'}, {'id': 207390, 'name': 'missing body'}]",
#  "[{'id': 4289, 'name': 'secret agent'}, {'id': 6162, 'name': 'past'}, {'id': 8015, 'name': 'cop'}, {'id': 14676, 'name': 'series of murders'}, {'id': 180668, 'name': 'homicide detective'}]",
#  "[{'id': 3616, 'name': 'college'}, {'id': 6075, 'name': 'sport'}, {'id': 6278, 'name': 'scholarship'}, {'id': 7813, 'name': 'hockey player'}, {'id': 7814, 'name': 'hockey coach'}, {'id': 18068, 'name': 'teenage boy'}]",
#  "[{'id': 529, 'name': 'ku klux klan'}, {'id': 3440, 'name': 'doomed man'}]",
#  ...]

# %%
import json

# %%
data = json.loads(df2)
data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 data = json.loads(df2)
#       2 data
#
# File ~\anaconda3\Lib\json\__init__.py:339, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337 else:
#     338     if not isinstance(s, (bytes, bytearray)):
# --> 339         raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     340                         f'not {s.__class__.__name__}')
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
#
# TypeError: the JSON object must be str, bytes or bytearray, not Series
